# %% [markdown]
# # New data sources: Our World in Data and Ember

# %%
# %pip install sidetable
# Out:
# Collecting sidetable
#   Downloading sidetable-0.9.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from sidetable) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->sidetable) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->sidetable) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->sidetable) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->sidetable) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0->sidetable) (1.16.0)
# Installing collected packages: sidetable
# Successfully installed sidetable-0.9.1

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sidetable as stb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1.Share with access to electricity vs. per capita energy consumption, 1990- 2021
# https://ourworldindata.org/grapher/share-with-access-to-electricity-vs-per-capita-energy-consumption
#
# Having access to electricity is defined in international statistics as having an electricity source that can provide very basic
# lighting, and charge a phone or power a radio for 4 hours per day. Primary energy is measured in kilowatt-hours per
# person, using the substitution method.

# %%
path='/content/drive/MyDrive/Hamoye_capstone_project_data/share-with-access-to-electricity-vs-per-capita-energy-consumption.csv'

# %%
df=pd.read_csv(path)
df.head()
# Out:
#         Entity      Code  Year  Access to electricity (% of population)  \
# 0     Abkhazia  OWID_ABK  2015                                      NaN
# 1  Afghanistan       AFG  2000                                 4.446891
# 2  Afghanistan       AFG  2001                                 9.294527
# 3  Afghanistan       AFG  2002                                14.133616
# 4  Afghanistan       AFG  2003                                18.971165
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                                NaN
# 1                                          302.59482
# 2                                          236.89185
# 3                                          210.86215
# 4                                          229.96822
#
#    Population (historical estimates) Continent
# 0                                NaN      Asia
# 1                         19542986.0       NaN
# 2                         19688634.0       NaN
# 3                         21000258.0       NaN
# 4                         22645136.0       NaN

# %%
# find Access to electricity (% of population) for Nigeria entity
nigeria_access=df[df['Entity']=='Nigeria'][['Year','Access to electricity (% of population)']]
#sort by year
nigeria_access=nigeria_access.sort_values(by='Year')
nigeria_access
# Out:
#         Year  Access to electricity (% of population)
# 37597 -10000                                      NaN
# 37598  -9000                                      NaN
# 37599  -8000                                      NaN
# 37600  -7000                                      NaN
# 37601  -6000                                      NaN
# ...      ...                                      ...
# 37582   2017                                     54.4
# 37583   2018                                     56.5
# 37584   2019                                     55.4
# 37585   2020                                     55.4
# 37586   2021                                     59.5
#
# [259 rows x 2 columns]

# %%
df.shape
# Out:
# (58668, 7)

# %%
entity= df.Entity.unique()
entity
# Out:
# array(['Abkhazia', 'Afghanistan', 'Africa', 'Africa (UN)',
#        'Akrotiri and Dhekelia', 'Aland Islands', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antarctica',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Asia',
#        'Asia (UN)', 'Australia', 'Austria', 'Austria-Hungary',
#        'Azerbaijan', 'Baden', 'Bahamas', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Bavaria', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Bouvet Island', 'Brazil',
#        'British Indian Ocean Territory', 'British Virgin Islands',
#        'Brunei', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia',
#        'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China', 'Christmas Island', 'Cocos Islands', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia',
#        'Czechoslovakia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic',
#        'East Asia and Pacific (WB)', 'East Germany', 'East Timor',
#        'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Ethiopia (former)', 'Europe',
#        'Europe (UN)', 'Europe and Central Asia (WB)',
#        'European Union (27)', 'Faeroe Islands', 'Falkland Islands',
#        'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Guiana',
#        'French Polynesia', 'French Southern Territories', 'Gabon',
#        'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece',
#        'Greenland', 'Grenada', 'Guadeloupe', 'Guam', 'Guatemala',
#        'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Hanover', 'Heard Island and McDonald Islands', 'Hesse Electoral',
#        'Hesse Grand Ducal', 'High-income countries', 'Honduras',
#        'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran',
#        'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica',
#        'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        'Korea (former)', 'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Laos',
#        'Latin America and Caribbean (WB)',
#        'Latin America and the Caribbean (UN)', 'Latvia', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
#        'Low-income countries', 'Lower-middle-income countries',
#        'Luxembourg', 'Macao', 'Madagascar', 'Malawi', 'Malaysia',
#        'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Martinique',
#        'Mauritania', 'Mauritius', 'Mayotte', 'Mecklenburg Schwerin',
#        'Mexico', 'Micronesia (country)',
#        'Middle East and North Africa (WB)', 'Middle-income countries',
#        'Modena', 'Moldova', 'Monaco', 'Mongolia', 'Montenegro',
#        'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Nagorno-Karabakh', 'Namibia', 'Nauru', 'Nepal', 'Netherlands',
#        'Netherlands Antilles', 'New Caledonia', 'New Zealand',
#        'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'Norfolk Island',
#        'North America', 'North America (WB)', 'North Korea',
#        'North Macedonia', 'Northern America (UN)', 'Northern Cyprus',
#        'Northern Mariana Islands', 'Norway', 'Oceania', 'Oceania (UN)',
#        'Oman', 'Pakistan', 'Palau', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Parma', 'Peru', 'Philippines',
#        'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
#        'Republic of Vietnam', 'Reunion', 'Romania', 'Russia', 'Rwanda',
#        'Saint Barthelemy', 'Saint Helena', 'Saint Kitts and Nevis',
#        'Saint Lucia', 'Saint Martin (French part)',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia',
#        'Saxony', 'Senegal', 'Serbia', 'Serbia and Montenegro',
#        'Serbia excluding Kosovo', 'Seychelles', 'Sierra Leone',
#        'Singapore', 'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'Somaliland', 'South Africa',
#        'South America', 'South Asia (WB)',
#        'South Georgia and the South Sandwich Islands', 'South Korea',
#        'South Ossetia', 'South Sudan', 'Spain', 'Sri Lanka',
#        'Sub-Saharan Africa (WB)', 'Sudan', 'Suriname',
#        'Svalbard and Jan Mayen', 'Sweden', 'Switzerland', 'Syria',
#        'Taiwan', 'Tajikistan', 'Tanzania', 'Thailand', 'Togo', 'Tokelau',
#        'Tonga', 'Transnistria', 'Trinidad and Tobago', 'Tunisia',
#        'Turkey', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuscany',
#        'Tuvalu', 'Two Sicilies', 'USSR', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'United States Minor Outlying Islands',
#        'United States Virgin Islands', 'Upper-middle-income countries',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican', 'Venezuela',
#        'Vietnam', 'Wallis and Futuna', 'West Germany', 'Western Sahara',
#        'World', 'Wuerttemburg', 'Yemen', 'Yemen Arab Republic',
#        "Yemen People's Republic", 'Yugoslavia', 'Zambia', 'Zanzibar',
#        'Zimbabwe'], dtype=object)

# %%
countries_ssa= ['Angola', 'Burundi', 'Benin', 'Burkina Faso', 'Botswana',
       'Central African Republic', "Cote d'Ivoire", 'Cameroon',
       'Congo, Dem. Rep.', 'Congo, Rep.', 'Comoros', 'Cabo Verde',
       'Djibouti','Eritrea', 'Ethiopia', 'Gabon', 'Ghana', 'Guinea', 'Gambia, The',
       'Guinea-Bissau', 'Equatorial Guinea', 'Kenya', 'Liberia',
       'Lesotho', 'Madagascar', 'Mali', 'Mozambique', 'Mauritania',
       'Mauritius', 'Malawi', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
       'Sudan', 'Senegal', 'Sierra Leone', 'Somalia', 'South Sudan',
       'Sao Tome and Principe', 'Eswatini', 'Seychelles', 'Chad', 'Togo',
       'Tanzania', 'Uganda', 'South Africa', 'Zambia', 'Zimbabwe']

# %%
#find countries from entity which are in countries_ssa
entity_ssa=[]
for i in entity:
  if i in countries_ssa:
    entity_ssa.append(i)

# %%
entity_ssa
# Out:
# ['Angola',
#  'Benin',
#  'Botswana',
#  'Burkina Faso',
#  'Burundi',
#  'Cameroon',
#  'Central African Republic',
#  'Chad',
#  'Comoros',
#  "Cote d'Ivoire",
#  'Djibouti',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Eswatini',
#  'Ethiopia',
#  'Gabon',
#  'Ghana',
#  'Guinea',
#  'Guinea-Bissau',
#  'Kenya',
#  'Lesotho',
#  'Liberia',
#  'Madagascar',
#  'Malawi',
#  'Mali',
#  'Mauritania',
#  'Mauritius',
#  'Mozambique',
#  'Namibia',
#  'Niger',
#  'Nigeria',
#  'Rwanda',
#  'Sao Tome and Principe',
#  'Senegal',
#  'Seychelles',
#  'Sierra Leone',
#  'Somalia',
#  'South Africa',
#  'South Sudan',
#  'Sudan',
#  'Tanzania',
#  'Togo',
#  'Uganda',
#  'Zambia',
#  'Zimbabwe']

# %%
len(entity_ssa)
# Out:
# 45

# %%
#find counties in countries_ssa which are not in entity_ssa3
ssa_no=[]
for i in countries_ssa:
  if i not in entity_ssa:
    ssa_no.append(i)
ssa_no
# Out:
# ['Congo, Dem. Rep.', 'Congo, Rep.', 'Cabo Verde', 'Gambia, The']

# %%
dict = {'Democratic Republic of Congo':'Congo, Dem. Rep.',
        'Congo':'Congo, Rep.',
        'Cape Verde':'Cabo Verde',
        'Gambia':'Gambia, The'}

# %%
#replace entities in df with the dictionary
df.replace({"Entity": dict}, inplace=True)

# %%
#find countries from entity which are in countries_ssa
entity_ssa=[]
for i in df.Entity.unique():
  if i in countries_ssa:
    entity_ssa.append(i)
len(entity_ssa)
# Out:
# 49

# %% [markdown]
# Now we have all 49 SSA countries in df!

# %%
#find entities with WB in it
regions_wb=[]
for i in entity:
  if 'WB' in i:
    regions_wb.append(i)
regions_wb
# Out:
# ['East Asia and Pacific (WB)',
#  'Europe and Central Asia (WB)',
#  'Latin America and Caribbean (WB)',
#  'Middle East and North Africa (WB)',
#  'North America (WB)',
#  'South Asia (WB)',
#  'Sub-Saharan Africa (WB)']

# %%
#find entities with UN in it
regions_un=[]
for i in entity:
  if 'UN' in i:
    regions_un.append(i)
regions_un
# Out:
# ['Africa (UN)',
#  'Asia (UN)',
#  'Europe (UN)',
#  'Latin America and the Caribbean (UN)',
#  'Northern America (UN)',
#  'Oceania (UN)']

# %%
#replace in df  'Northern America (UN)' with 'North America (UN)'
df.replace({'Northern America (UN)': 'North America (UN)', 'Latin America and the Caribbean (UN)':'Latin America and Caribbean (UN)'}, inplace=True)

# %%
regions_un=[]
for i in df.Entity.unique():
  if 'UN' in i:
    regions_un.append(i)
regions_un
# Out:
# ['Africa (UN)',
#  'Asia (UN)',
#  'Europe (UN)',
#  'Latin America and Caribbean (UN)',
#  'North America (UN)',
#  'Oceania (UN)']

# %%
df.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Access to electricity (% of population)',
#        'Primary energy consumption per capita (kWh/person)',
#        'Population (historical estimates)', 'Continent'],
#       dtype='object')

# %% [markdown]
# Let's take only WB regions, because only in WB splitting Sub-Saharan Africa is present

# %%
# Combine all valid entities into a single list
valid_entities = entity_ssa + regions_wb  + regions_un + ['World']

# Select rows for valid entities
access_consum = df[df['Entity'].isin(valid_entities)]

# Drop columns 'Code' and 'Continent'
access_consum = access_consum.drop(['Code', 'Continent'], axis=1)

# %%
#For consistansy it merging with other tables replace '(UN)' with '()' in entities
access_consum['Entity'] = access_consum['Entity'].str.replace(' (UN)', ' ()')

# %%
access_consum.head()
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 520  Africa ()  1950                                      NaN
# 521  Africa ()  1951                                      NaN
# 522  Africa ()  1952                                      NaN
# 523  Africa ()  1953                                      NaN
# 524  Africa ()  1954                                      NaN
#
#      Primary energy consumption per capita (kWh/person)  \
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
# 524                                                NaN
#
#      Population (historical estimates)
# 520                        227549264.0
# 521                        232484000.0
# 522                        237586064.0
# 523                        242837440.0
# 524                        248244768.0

# %%
access_consum.shape
# Out:
# (13433, 5)

# %%
access_consum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13433 entries, 520 to 58667
# Data columns (total 5 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Entity                                              13433 non-null  object
#  1   Year                                                13433 non-null  int64
#  2   Access to electricity (% of population)             1484 non-null   float64
#  3   Primary energy consumption per capita (kWh/person)  2076 non-null   float64
#  4   Population (historical estimates)                   13238 non-null  float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 629.7+ KB

# %%
access_consum.describe()
# Out:
#                Year  Access to electricity (% of population)  \
# count  13433.000000                              1484.000000
# mean    1596.461178                                44.090754
# std     1451.377512                                30.579460
# min   -10000.000000                                 0.533899
# 25%     1833.000000                                17.096379
# 50%     1900.000000                                38.018265
# 75%     1965.000000                                65.014345
# max     2022.000000                               100.000000
#
#        Primary energy consumption per capita (kWh/person)  \
# count                                        2076.000000
# mean                                         4215.676742
# std                                          7514.099088
# min                                            99.053375
# 25%                                           560.443715
# 50%                                          1391.890250
# 75%                                          3493.160725
# max                                         57886.984000
#
#        Population (historical estimates)
# count                       1.323800e+04
# mean                        7.678257e+07
# std                         4.843163e+08
# min                         2.000000e+00
# 25%                         3.223560e+05
# 50%                         1.469053e+06
# 75%                         4.483672e+06
# max                         7.909295e+09

# %%
#find rows with year < 0
access_consum[access_consum['Year']<0]
# Out:
#          Entity   Year  Access to electricity (% of population)  \
# 1531     Angola -10000                                      NaN
# 1532     Angola  -9000                                      NaN
# 1533     Angola  -8000                                      NaN
# 1534     Angola  -7000                                      NaN
# 1535     Angola  -6000                                      NaN
# ...         ...    ...                                      ...
# 58456  Zimbabwe  -5000                                      NaN
# 58457  Zimbabwe  -4000                                      NaN
# 58458  Zimbabwe  -3000                                      NaN
# 58459  Zimbabwe  -2000                                      NaN
# 58460  Zimbabwe  -1000                                      NaN
#
#        Primary energy consumption per capita (kWh/person)  \
# 1531                                                 NaN
# 1532                                                 NaN
# 1533                                                 NaN
# 1534                                                 NaN
# 1535                                                 NaN
# ...                                                  ...
# 58456                                                NaN
# 58457                                                NaN
# 58458                                                NaN
# 58459                                                NaN
# 58460                                                NaN
#
#        Population (historical estimates)
# 1531                               379.0
# 1532                               633.0
# 1533                              1055.0
# 1534                              1758.0
# 1535                              2930.0
# ...                                  ...
# 58456                             5692.0
# 58457                             8538.0
# 58458                            12807.0
# 58459                            19211.0
# 58460                            28817.0
#
# [450 rows x 5 columns]

# %%
#take all rows for Angola
access_consum[access_consum['Entity']=='Angola']
# Out:
#       Entity  Year  Access to electricity (% of population)  \
# 1489  Angola  2000                                24.238865
# 1490  Angola  2001                                20.000000
# 1491  Angola  2002                                26.320255
# 1492  Angola  2003                                27.355137
# 1493  Angola  2004                                28.395485
# ...      ...   ...                                      ...
# 1743  Angola  1975                                      NaN
# 1744  Angola  1976                                      NaN
# 1745  Angola  1977                                      NaN
# 1746  Angola  1978                                      NaN
# 1747  Angola  1979                                      NaN
#
#       Primary energy consumption per capita (kWh/person)  \
# 1489                                          1979.2562
# 1490                                          2079.7320
# 1491                                          2143.5280
# 1492                                          2298.9023
# 1493                                          2454.6700
# ...                                                 ...
# 1743                                                NaN
# 1744                                                NaN
# 1745                                                NaN
# 1746                                                NaN
# 1747                                                NaN
#
#       Population (historical estimates)
# 1489                         16394067.0
# 1490                         16941584.0
# 1491                         17516140.0
# 1492                         18124346.0
# 1493                         18771128.0
# ...                                 ...
# 1743                          7032728.0
# 1744                          7266788.0
# 1745                          7511898.0
# 1746                          7771595.0
# 1747                          8043223.0
#
# [259 rows x 5 columns]

# %% [markdown]
# There can't be 259 rows for Angola for the period 1990-2021, as it's stated in the table description. Let's drop years below 1990.

# %%
#drop rows where year < 1990
access_consum=access_consum[access_consum['Year']>=1990]

# %%
access_consum.shape
# Out:
# (1987, 5)

# %%
access_consum.describe()
# Out:
#               Year  Access to electricity (% of population)  \
# count  1987.000000                              1484.000000
# mean   2005.703573                                44.090754
# std       9.187167                                30.579460
# min    1990.000000                                 0.533899
# 25%    1998.000000                                17.096379
# 50%    2006.000000                                38.018265
# 75%    2014.000000                                65.014345
# max    2022.000000                               100.000000
#
#        Primary energy consumption per capita (kWh/person)  \
# count                                        1576.000000
# mean                                         4281.153401
# std                                          7857.723361
# min                                            99.053375
# 25%                                           574.033783
# 50%                                          1455.430000
# 75%                                          3369.350825
# max                                         57886.984000
#
#        Population (historical estimates)
# count                       1.792000e+03
# mean                        2.506803e+08
# std                         1.026765e+09
# min                         7.107300e+04
# 25%                         2.312693e+06
# 50%                         1.081645e+07
# 75%                         2.887949e+07
# max                         7.909295e+09

# %%
access_consum.stb.missing()
# Out:
#                                                     missing  total    percent
# Access to electricity (% of population)                 503   1987  25.314545
# Primary energy consumption per capita (kWh/person)      411   1987  20.684449
# Population (historical estimates)                       195   1987   9.813790
# Entity                                                    0   1987   0.000000
# Year                                                      0   1987   0.000000

# %%
missing_values_per_year = access_consum.groupby('Year').apply(lambda x: x.isnull().sum())
missing_values_per_year
# Out:
#       Entity  Year  Access to electricity (% of population)  \
# Year
# 1990       0     0                                       52
# 1991       0     0                                       49
# 1992       0     0                                       43
# 1993       0     0                                       39
# 1994       0     0                                       36
# 1995       0     0                                       34
# 1996       0     0                                       29
# 1997       0     0                                       26
# 1998       0     0                                       23
# 1999       0     0                                       22
# 2000       0     0                                        9
# 2001       0     0                                        9
# 2002       0     0                                        8
# 2003       0     0                                        8
# 2004       0     0                                        8
# 2005       0     0                                        8
# 2006       0     0                                        8
# 2007       0     0                                        6
# 2008       0     0                                        6
# 2009       0     0                                        6
# 2010       0     0                                        6
# 2011       0     0                                        6
# 2012       0     0                                        6
# 2013       0     0                                        6
# 2014       0     0                                        6
# 2015       0     0                                        6
# 2016       0     0                                        6
# 2017       0     0                                        6
# 2018       0     0                                        6
# 2019       0     0                                        6
# 2020       0     0                                        6
# 2021       0     0                                        6
# 2022       0     0                                        2
#
#       Primary energy consumption per capita (kWh/person)  \
# Year
# 1990                                                 10
# 1991                                                 10
# 1992                                                 11
# 1993                                                 12
# 1994                                                 11
# 1995                                                 11
# 1996                                                 12
# 1997                                                 12
# 1998                                                 12
# 1999                                                 12
# 2000                                                 14
# 2001                                                 14
# 2002                                                 14
# 2003                                                 14
# 2004                                                 14
# 2005                                                 14
# 2006                                                 14
# 2007                                                 14
# 2008                                                 14
# 2009                                                 14
# 2010                                                 14
# 2011                                                 14
# 2012                                                 13
# 2013                                                 13
# 2014                                                 13
# 2015                                                 13
# 2016                                                 13
# 2017                                                 13
# 2018                                                 13
# 2019                                                 13
# 2020                                                 13
# 2021                                                 13
# 2022                                                  0
#
#       Population (historical estimates)
# Year
# 1990                                  2
# 1991                                  2
# 1992                                  3
# 1993                                  4
# 1994                                  4
# 1995                                  4
# 1996                                  5
# 1997                                  5
# 1998                                  5
# 1999                                  5
# 2000                                  7
# 2001                                  7
# 2002                                  7
# 2003                                  7
# 2004                                  7
# 2005                                  7
# 2006                                  7
# 2007                                  7
# 2008                                  7
# 2009                                  7
# 2010                                  7
# 2011                                  7
# 2012                                  7
# 2013                                  7
# 2014                                  7
# 2015                                  7
# 2016                                  7
# 2017                                  7
# 2018                                  7
# 2019                                  7
# 2020                                  7
# 2021                                  7
# 2022                                  2

# %%
#show rows with missing 'Access to electricity (% of population)'
access_consum[access_consum['Access to electricity (% of population)'].isnull()]
# Out:
#           Entity  Year  Access to electricity (% of population)  \
# 560    Africa ()  1990                                      NaN
# 561    Africa ()  1991                                      NaN
# 562    Africa ()  1992                                      NaN
# 563    Africa ()  1993                                      NaN
# 564    Africa ()  1994                                      NaN
# ...          ...   ...                                      ...
# 57558      World  1996                                      NaN
# 57559      World  1997                                      NaN
# 57560      World  2022                                      NaN
# 58449   Zimbabwe  1990                                      NaN
# 58450   Zimbabwe  1991                                      NaN
#
#        Primary energy consumption per capita (kWh/person)  \
# 560                                                  NaN
# 561                                                  NaN
# 562                                                  NaN
# 563                                                  NaN
# 564                                                  NaN
# ...                                                  ...
# 57558                                         17848.8380
# 57559                                         17785.1480
# 57560                                         21038.9300
# 58449                                          6057.5283
# 58450                                          6036.0913
#
#        Population (historical estimates)
# 560                         6.381572e+08
# 561                         6.550405e+08
# 562                         6.719315e+08
# 563                         6.891400e+08
# 564                         7.064883e+08
# ...                                  ...
# 57558                       5.825145e+09
# 57559                       5.906481e+09
# 57560                                NaN
# 58449                       1.011390e+07
# 58450                       1.037782e+07
#
# [503 rows x 5 columns]

# %% [markdown]
# ##2.Electricity generation, 2023
# Measured in terawatt-hours.
# 1985-2023
#
# Total electricity generation Ember and Energy Institute
# Source
# Ember (2024); Energy Institute - Statistical Review of World Energy (2023) – with major processing by Our World in Data
# Last updated
# May 8, 2024
#
# https://ourworldindata.org/grapher/electricity-generation

# %%
path='/content/drive/MyDrive/Hamoye_capstone_project_data/electricity-generation.csv'

# %%
df2=pd.read_csv(path)
df2.head()
# Out:
#           Entity Code  Year  Electricity generation - TWh
# 0  ASEAN (Ember)  NaN  2000                        378.61
# 1  ASEAN (Ember)  NaN  2001                        404.85
# 2  ASEAN (Ember)  NaN  2002                        433.19
# 3  ASEAN (Ember)  NaN  2003                        458.24
# 4  ASEAN (Ember)  NaN  2004                        496.56

# %%
df2.shape
# Out:
# (7382, 4)

# %%
entity2=df2.Entity.unique()
entity2
# Out:
# array(['ASEAN (Ember)', 'Afghanistan', 'Africa', 'Africa (EI)',
#        'Africa (Ember)', 'Albania', 'Algeria', 'American Samoa', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Asia',
#        'Asia (Ember)', 'Asia Pacific (EI)', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'CIS (EI)', 'Cambodia', 'Cameroon', 'Canada',
#        'Cape Verde', 'Cayman Islands', 'Central African Republic',
#        'Central America (EI)', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Cyprus', 'Czechia',
#        'Democratic Republic of Congo', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'East Timor', 'Eastern Africa (EI)',
#        'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Europe', 'Europe (EI)',
#        'Europe (Ember)', 'European Union (27)', 'Falkland Islands',
#        'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Guiana',
#        'French Polynesia', 'G20 (Ember)', 'G7 (Ember)', 'Gabon', 'Gambia',
#        'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland',
#        'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guinea',
#        'Guinea-Bissau', 'Guyana', 'Haiti', 'High-income countries',
#        'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Laos',
#        'Latin America and Caribbean (Ember)', 'Latvia', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Lithuania', 'Low-income countries',
#        'Lower-middle-income countries', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Martinique', 'Mauritania', 'Mauritius', 'Mexico',
#        'Middle Africa (EI)', 'Middle East (EI)', 'Middle East (Ember)',
#        'Moldova', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco',
#        'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
#        'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua',
#        'Niger', 'Nigeria', 'Niue', 'Non-OECD (EI)', 'North America',
#        'North America (EI)', 'North America (Ember)', 'North Korea',
#        'North Macedonia', 'Norway', 'OECD (EI)', 'OECD (Ember)',
#        'Oceania', 'Oceania (Ember)', 'Oman', 'Pakistan', 'Palestine',
#        'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines',
#        'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Reunion', 'Romania',
#        'Russia', 'Rwanda', 'Saint Helena', 'Saint Kitts and Nevis',
#        'Saint Lucia', 'Saint Pierre and Miquelon',
#        'Saint Vincent and the Grenadines', 'Samoa',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'South and Central America (EI)',
#        'Spain', 'Sri Lanka', 'Sudan', 'Suriname', 'Sweden', 'Switzerland',
#        'Syria', 'Taiwan', 'Tajikistan', 'Tanzania', 'Thailand', 'Togo',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'United States Virgin Islands', 'Upper-middle-income countries',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'Western Africa (EI)', 'Western Sahara', 'World', 'Yemen',
#        'Zambia', 'Zimbabwe'], dtype=object)

# %%
#find entities which are in countries_ssa
entity_ssa2=[]
for i in entity2:
  if i in countries_ssa:
    entity_ssa2.append(i)
entity_ssa2
# Out:
# ['Angola',
#  'Benin',
#  'Botswana',
#  'Burkina Faso',
#  'Burundi',
#  'Cameroon',
#  'Central African Republic',
#  'Chad',
#  'Comoros',
#  "Cote d'Ivoire",
#  'Djibouti',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Eswatini',
#  'Ethiopia',
#  'Gabon',
#  'Ghana',
#  'Guinea',
#  'Guinea-Bissau',
#  'Kenya',
#  'Lesotho',
#  'Liberia',
#  'Madagascar',
#  'Malawi',
#  'Mali',
#  'Mauritania',
#  'Mauritius',
#  'Mozambique',
#  'Namibia',
#  'Niger',
#  'Nigeria',
#  'Rwanda',
#  'Sao Tome and Principe',
#  'Senegal',
#  'Seychelles',
#  'Sierra Leone',
#  'Somalia',
#  'South Africa',
#  'South Sudan',
#  'Sudan',
#  'Tanzania',
#  'Togo',
#  'Uganda',
#  'Zambia',
#  'Zimbabwe']

# %%
len(entity_ssa2)
# Out:
# 45

# %%
#find counties in countries_ssa which are not in entity_ssa2
ssa_no2=[]
for i in countries_ssa:
  if i not in entity_ssa2:
    ssa_no2.append(i)
ssa_no2
# Out:
# ['Congo, Dem. Rep.', 'Congo, Rep.', 'Cabo Verde', 'Gambia, The']

# %% [markdown]
# The same issue as in df above. Replace with the same dictionary.

# %%
#replace entities in df2 with the dictionary
df2.replace({"Entity": dict}, inplace=True)

# %%
#find countries from entity which are in countries_ssa
entity_ssa2=[]
for i in df2.Entity.unique():
  if i in countries_ssa:
    entity_ssa2.append(i)
len(entity_ssa2)
# Out:
# 49

# %%
#find entities with Ember in it:
regions_ember=[]
for i in entity2:
  if 'Ember' in i:
    regions_ember.append(i)
regions_ember
# Out:
# ['ASEAN (Ember)',
#  'Africa (Ember)',
#  'Asia (Ember)',
#  'Europe (Ember)',
#  'G20 (Ember)',
#  'G7 (Ember)',
#  'Latin America and Caribbean (Ember)',
#  'Middle East (Ember)',
#  'North America (Ember)',
#  'OECD (Ember)',
#  'Oceania (Ember)']

# %%
regions_un
# Out:
# ['Africa (UN)',
#  'Asia (UN)',
#  'Europe (UN)',
#  'Latin America and Caribbean (UN)',
#  'North America (UN)',
#  'Oceania (UN)']

# %%
regions_wb
# Out:
# ['East Asia and Pacific (WB)',
#  'Europe and Central Asia (WB)',
#  'Latin America and Caribbean (WB)',
#  'Middle East and North Africa (WB)',
#  'North America (WB)',
#  'South Asia (WB)',
#  'Sub-Saharan Africa (WB)']

# %% [markdown]
# So, regions by Ember are most close to regions by UN, added G&, G20, OEDC. Let's take only those regions from Ember which are equal to UN regions.

# %%
regions_ember = [
 'Africa (Ember)',
 'Asia (Ember)',
 'Europe (Ember)',
 'Latin America and Caribbean (Ember)',
 'Middle East (Ember)',
 'North America (Ember)',
 'Oceania (Ember)']

# %%
valid_entities = entity_ssa2 + regions_ember  + ['World']

# Select rows for valid entities
elec_generation = df2[df2['Entity'].isin(valid_entities)]

# Drop columns 'Code'
elec_generation = elec_generation.drop(['Code'], axis=1)
elec_generation.head()
# Out:
#              Entity  Year  Electricity generation - TWh
# 123  Africa (Ember)  2000                        441.08
# 124  Africa (Ember)  2001                        459.46
# 125  Africa (Ember)  2002                        487.69
# 126  Africa (Ember)  2003                        509.14
# 127  Africa (Ember)  2004                        540.14

# %%
elec_generation['Entity'] = elec_generation['Entity'].str.replace(' (Ember)', ' ()')
elec_generation.head(2)
# Out:
#         Entity  Year  Electricity generation - TWh
# 123  Africa ()  2000                        441.08
# 124  Africa ()  2001                        459.46

# %%
elec_generation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1340 entries, 123 to 7381
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Entity                        1340 non-null   object
#  1   Year                          1340 non-null   int64
#  2   Electricity generation - TWh  1340 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 41.9+ KB

# %%
#find data for 'Sudan'
elec_generation[elec_generation['Entity']=='Sudan']
# Out:
#      Entity  Year  Electricity generation - TWh
# 6347  Sudan  2000                          2.54
# 6348  Sudan  2001                          2.68
# 6349  Sudan  2002                          3.00
# 6350  Sudan  2003                          3.47
# 6351  Sudan  2004                          3.60
# 6352  Sudan  2005                          3.96
# 6353  Sudan  2006                          4.65
# 6354  Sudan  2007                          5.16
# 6355  Sudan  2008                          5.64
# 6356  Sudan  2009                          6.61
# 6357  Sudan  2010                          7.58
# 6358  Sudan  2011                          8.51
# 6359  Sudan  2012                          9.50
# 6360  Sudan  2013                         10.35
# 6361  Sudan  2014                         11.41
# 6362  Sudan  2015                         13.09
# 6363  Sudan  2016                         14.57
# 6364  Sudan  2017                         15.70
# 6365  Sudan  2018                         16.40
# 6366  Sudan  2019                         16.22
# 6367  Sudan  2020                         17.20
# 6368  Sudan  2021                         17.70
# 6369  Sudan  2022                         17.86

# %% [markdown]
# ## 3.Electricity production by source
# https://ourworldindata.org/grapher/electricity-prod-source-stacked?country=OWID_WRL~OWID_AFR~DZA~AGO~TCD
#
# Measured in terawatt-hours. 1985-2023

# %%
df3=pd.read_csv('/content/drive/MyDrive/Hamoye_capstone_project_data/electricity-production-by-source.csv')
df3.head()
# Out:
#           Entity Code  Year  Electricity from coal - TWh  \
# 0  ASEAN (Ember)  NaN  2000                        76.03
# 1  ASEAN (Ember)  NaN  2001                        86.26
# 2  ASEAN (Ember)  NaN  2002                        93.43
# 3  ASEAN (Ember)  NaN  2003                       102.01
# 4  ASEAN (Ember)  NaN  2004                       115.01
#
#    Electricity from gas - TWh  Electricity from nuclear - TWh  \
# 0                      164.26                             0.0
# 1                      190.41                             0.0
# 2                      208.92                             0.0
# 3                      226.51                             0.0
# 4                      244.16                             0.0
#
#    Electricity from hydro - TWh  Electricity from solar - TWh  \
# 0                         50.45                           0.0
# 1                         54.33                           0.0
# 2                         53.29                           0.0
# 3                         53.21                           0.0
# 4                         52.99                           0.0
#
#    Electricity from oil - TWh  Electricity from wind - TWh  \
# 0                       65.07                          0.0
# 1                       50.99                          0.0
# 2                       54.32                          0.0
# 3                       53.32                          0.0
# 4                       59.43                          0.0
#
#    Electricity from bioenergy - TWh  \
# 0                              5.87
# 1                              6.46
# 2                              6.62
# 3                              7.45
# 4                              8.40
#
#    Other renewables excluding bioenergy - TWh
# 0                                       16.93
# 1                                       16.40
# 2                                       16.61
# 3                                       15.74
# 4                                       16.57

# %%
entity3=df3.Entity.unique()
entity3
# Out:
# array(['ASEAN (Ember)', 'Afghanistan', 'Africa', 'Africa (EI)',
#        'Africa (Ember)', 'Albania', 'Algeria', 'American Samoa', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Asia',
#        'Asia (Ember)', 'Asia Pacific (EI)', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'CIS (EI)', 'Cambodia', 'Cameroon', 'Canada',
#        'Cape Verde', 'Cayman Islands', 'Central African Republic',
#        'Central America (EI)', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia',
#        'Democratic Republic of Congo', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'East Timor', 'Eastern Africa (EI)',
#        'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Europe', 'Europe (EI)',
#        'Europe (Ember)', 'European Union (27)', 'Falkland Islands',
#        'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Guiana',
#        'French Polynesia', 'G20 (Ember)', 'G7 (Ember)', 'Gabon', 'Gambia',
#        'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland',
#        'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guinea',
#        'Guinea-Bissau', 'Guyana', 'Haiti', 'High-income countries',
#        'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Laos',
#        'Latin America and Caribbean (Ember)', 'Latvia', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Lithuania', 'Low-income countries',
#        'Lower-middle-income countries', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Martinique', 'Mauritania', 'Mauritius', 'Mexico',
#        'Middle Africa (EI)', 'Middle East (EI)', 'Middle East (Ember)',
#        'Moldova', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco',
#        'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
#        'Netherlands', 'Netherlands Antilles', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'Non-OECD (EI)', 'North America', 'North America (EI)',
#        'North America (Ember)', 'North Korea', 'North Macedonia',
#        'Norway', 'OECD (EI)', 'OECD (Ember)', 'Oceania',
#        'Oceania (Ember)', 'Oman', 'Pakistan', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland',
#        'Portugal', 'Puerto Rico', 'Qatar', 'Reunion', 'Romania', 'Russia',
#        'Rwanda', 'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'Sao Tome and Principe', 'Saudi Arabia', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia',
#        'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa',
#        'South America', 'South Korea', 'South Sudan',
#        'South and Central America (EI)', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'USSR', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'United States Virgin Islands', 'Upper-middle-income countries',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'Western Africa (EI)', 'Western Sahara', 'World', 'Yemen',
#        'Zambia', 'Zimbabwe'], dtype=object)

# %%
#find countries in df3 which are in countries_ssa
entity_ssa3=[]
for i in entity3:
  if i in countries_ssa:
    entity_ssa3.append(i)
len(entity_ssa3)
# Out:
# 45

# %%
#find counties in countries_ssa which are not in entity_ssa3
ssa_no3=[]
for i in countries_ssa:
  if i not in entity_ssa3:
    ssa_no3.append(i)
ssa_no3
# Out:
# ['Congo, Dem. Rep.', 'Congo, Rep.', 'Cabo Verde', 'Gambia, The']

# %%
#replace entity in df3 with the dictionary
df3.replace({"Entity": dict}, inplace=True)

# %%
#find countries from entity which are in countries_ssa
entity_ssa3=[]
for i in df3.Entity.unique():
  if i in countries_ssa:
    entity_ssa3.append(i)
len(entity_ssa3)
# Out:
# 49

# %%
regions_ember
# Out:
# ['Africa (Ember)',
#  'Asia (Ember)',
#  'Europe (Ember)',
#  'Latin America and Caribbean (Ember)',
#  'Middle East (Ember)',
#  'North America (Ember)',
#  'Oceania (Ember)']

# %%
valid_entities = entity_ssa3 + regions_ember  + ['World']

# Select rows for valid entities
elec_production = df3[df3['Entity'].isin(valid_entities)]

# Drop columns 'Code'
elec_production = elec_production.drop(['Code'], axis=1)
elec_production.head(2)
# Out:
#              Entity  Year  Electricity from coal - TWh  \
# 163  Africa (Ember)  2000                       211.52
# 164  Africa (Ember)  2001                       216.72
#
#      Electricity from gas - TWh  Electricity from nuclear - TWh  \
# 163                       91.85                           13.01
# 164                      100.98                           10.72
#
#      Electricity from hydro - TWh  Electricity from solar - TWh  \
# 163                         74.85                          0.01
# 164                         80.30                          0.01
#
#      Electricity from oil - TWh  Electricity from wind - TWh  \
# 163                       47.20                         0.17
# 164                       47.73                         0.42
#
#      Electricity from bioenergy - TWh  \
# 163                              2.04
# 164                              2.10
#
#      Other renewables excluding bioenergy - TWh
# 163                                        0.43
# 164                                        0.48

# %%
elec_production['Entity'] = elec_production['Entity'].str.replace(' (Ember)', ' ()')
elec_production.head(2)
# Out:
#         Entity  Year  Electricity from coal - TWh  Electricity from gas - TWh  \
# 163  Africa ()  2000                       211.52                       91.85
# 164  Africa ()  2001                       216.72                      100.98
#
#      Electricity from nuclear - TWh  Electricity from hydro - TWh  \
# 163                           13.01                         74.85
# 164                           10.72                         80.30
#
#      Electricity from solar - TWh  Electricity from oil - TWh  \
# 163                          0.01                       47.20
# 164                          0.01                       47.73
#
#      Electricity from wind - TWh  Electricity from bioenergy - TWh  \
# 163                         0.17                              2.04
# 164                         0.42                              2.10
#
#      Other renewables excluding bioenergy - TWh
# 163                                        0.43
# 164                                        0.48

# %%
#drop years below 1990
elec_production=elec_production[elec_production['Year']>=1990]
elec_production.shape
# Out:
# (1452, 11)

# %%
elec_production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1452 entries, 163 to 9876
# Data columns (total 11 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Entity                                      1452 non-null   object
#  1   Year                                        1452 non-null   int64
#  2   Electricity from coal - TWh                 1330 non-null   float64
#  3   Electricity from gas - TWh                  1330 non-null   float64
#  4   Electricity from nuclear - TWh              1452 non-null   float64
#  5   Electricity from hydro - TWh                1330 non-null   float64
#  6   Electricity from solar - TWh                1330 non-null   float64
#  7   Electricity from oil - TWh                  1330 non-null   float64
#  8   Electricity from wind - TWh                 1330 non-null   float64
#  9   Electricity from bioenergy - TWh            1310 non-null   float64
#  10  Other renewables excluding bioenergy - TWh  1286 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 136.1+ KB

# %%
elec_production.describe()
# Out:
#               Year  Electricity from coal - TWh  Electricity from gas - TWh  \
# count  1452.000000                  1330.000000                 1330.000000
# mean   2009.648072                   349.630826                  192.391906
# std       7.937956                  1432.876301                  741.751618
# min    1990.000000                     0.000000                    0.000000
# 25%    2004.000000                     0.000000                    0.000000
# 50%    2010.000000                     0.000000                    0.000000
# 75%    2016.000000                     0.185000                    0.890000
# max    2023.000000                 10467.930000                 6622.930000
#
#        Electricity from nuclear - TWh  Electricity from hydro - TWh  \
# count                     1452.000000                   1330.000000
# mean                       103.006030                    146.686472
# std                        424.869579                    558.165267
# min                          0.000000                      0.000000
# 25%                          0.000000                      0.010000
# 50%                          0.000000                      0.751000
# 75%                          0.000000                      5.925000
# max                       2762.240000                   4344.050000
#
#        Electricity from solar - TWh  Electricity from oil - TWh  \
# count                   1330.000000                 1330.000000
# mean                      11.718826                   49.579214
# std                       86.742597                  192.165760
# min                        0.000000                    0.000000
# 25%                        0.000000                    0.030000
# 50%                        0.000000                    0.250000
# 75%                        0.020000                    1.137500
# max                     1629.900000                 1364.684400
#
#        Electricity from wind - TWh  Electricity from bioenergy - TWh  \
# count                  1330.000000                       1310.000000
# mean                     26.133278                         14.018229
# std                     150.422714                         63.392902
# min                       0.000000                          0.000000
# 25%                       0.000000                          0.000000
# 50%                       0.000000                          0.000000
# 75%                       0.000000                          0.110000
# max                    2304.440000                        678.740000
#
#        Other renewables excluding bioenergy - TWh
# count                                 1286.000000
# mean                                     2.475062
# std                                      9.867454
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                     89.810000

# %% [markdown]
# ## 4.Per capita electricity generation, 2023
#
# Annual average electricity generation per person, measured in kilowatt-hours. 1985-2023
#
# https://ourworldindata.org/explorers/energy?Metric=Per+capita+generation&Total+or+Breakdown=Total&Energy+or+Electricity=Electricity+only

# %%
df4=pd.read_csv('/content/drive/MyDrive/Hamoye_capstone_project_data/per-capita-electricity-generation.csv')
df4.head()
# Out:
#         Entity Code  Year  Per capita electricity - kWh
# 0  Afghanistan  AFG  2000                     24.561241
# 1  Afghanistan  AFG  2001                     35.045600
# 2  Afghanistan  AFG  2002                     33.809110
# 3  Afghanistan  AFG  2003                     40.185230
# 4  Afghanistan  AFG  2004                     33.540585

# %%
entity4=df4.Entity.unique()
entity4
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Cyprus', 'Czechia',
#        'Democratic Republic of Congo', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'East Timor', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union (27)',
#        'Falkland Islands', 'Faroe Islands', 'Fiji', 'Finland', 'France',
#        'French Guiana', 'French Polynesia', 'Gabon', 'Gambia', 'Georgia',
#        'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guadeloupe', 'Guam', 'Guatemala', 'Guinea', 'Guinea-Bissau',
#        'Guyana', 'Haiti', 'High-income countries', 'Honduras',
#        'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran',
#        'Iraq', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan',
#        'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Lithuania', 'Low-income countries',
#        'Lower-middle-income countries', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Martinique', 'Mauritania', 'Mauritius', 'Mexico', 'Moldova',
#        'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique',
#        'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands',
#        'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria',
#        'Niue', 'North America', 'North Korea', 'North Macedonia',
#        'Norway', 'Oceania', 'Oman', 'Pakistan', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland',
#        'Portugal', 'Puerto Rico', 'Qatar', 'Reunion', 'Romania', 'Russia',
#        'Rwanda', 'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'Sao Tome and Principe', 'Saudi Arabia', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia',
#        'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa',
#        'South America', 'South Korea', 'South Sudan', 'Spain',
#        'Sri Lanka', 'Sudan', 'Suriname', 'Sweden', 'Switzerland', 'Syria',
#        'Taiwan', 'Tajikistan', 'Tanzania', 'Thailand', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'United States Virgin Islands', 'Upper-middle-income countries',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'Western Sahara', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
#which entities are in countries_ssa
entity_ssa4=[]
for i in entity4:
  if i in countries_ssa:
    entity_ssa4.append(i)
len(entity_ssa4)
# Out:
# 45

# %%
#which ssa countries are not in entity4
ssa_no4=[]
for i in countries_ssa:
  if i not in entity_ssa4:
    ssa_no4.append(i)
ssa_no4
# Out:
# ['Congo, Dem. Rep.', 'Congo, Rep.', 'Cabo Verde', 'Gambia, The']

# %%
#replace countries with the dictionary
df4.replace({"Entity": dict}, inplace=True)

# %%
#find countries from entity which are now in countries_ssa
entity_ssa4=[]
for i in df4.Entity.unique():
  if i in countries_ssa:
    entity_ssa4.append(i)
len(entity_ssa4)
# Out:
# 49

# %% [markdown]
# Aggregated values per regions are not marked with () in df4, but we can do it. Only 1 refion is marked - 'European Union (27)'

# %%
regions4=['Africa', 'North America', 'South America', 'Asia', 'Europe', 'Oceania', 'World']

# %%
regions_ember
# Out:
# ['Africa (Ember)',
#  'Asia (Ember)',
#  'Europe (Ember)',
#  'Latin America and Caribbean (Ember)',
#  'Middle East (Ember)',
#  'North America (Ember)',
#  'Oceania (Ember)']

# %%
regions_un
# Out:
# ['Africa (UN)',
#  'Asia (UN)',
#  'Europe (UN)',
#  'Latin America and Caribbean (UN)',
#  'North America (UN)',
#  'Oceania (UN)']

# %% [markdown]
# So, in df4 regions are not totally equal to regions_ember,regions_un. Let's mark them by ().

# %%
regions4=['Africa ()', 'North America ()', 'Latin America and Caribbean ()', 'Asia ()', 'Europe ()', 'Oceania ()']

# %%
dict_regions = {'Africa': 'Africa ()', 'North America': 'North America ()', 'South America': 'Latin America and Caribbean ()', 'Asia': 'Asia ()', 'Europe': 'Europe ()', 'Oceania': 'Oceania ()'}

# %%
#replace entities from df4.Entity with the dict_regions
df4.replace({"Entity": dict_regions}, inplace=True)

# %%
valid_entities = entity_ssa4 + regions4+ ['World']

# Select rows for valid entities
elec_generation_pc = df4[df4['Entity'].isin(valid_entities)]

# Drop columns 'Code'
elec_generation_pc = elec_generation_pc.drop(['Code'], axis=1)
elec_generation_pc
# Out:
#          Entity  Year  Per capita electricity - kWh
# 23    Africa ()  1985                     466.09274
# 24    Africa ()  1986                     472.51150
# 25    Africa ()  1987                     476.56700
# 26    Africa ()  1988                     488.48640
# 27    Africa ()  1989                     493.66330
# ...         ...   ...                           ...
# 6619   Zimbabwe  2018                     627.15125
# 6620   Zimbabwe  2019                     552.92850
# 6621   Zimbabwe  2020                     428.21597
# 6622   Zimbabwe  2021                     528.96410
# 6623   Zimbabwe  2022                     547.16327
#
# [1400 rows x 3 columns]

# %%
#drop years below 1990
elec_generation_pc=elec_generation_pc[elec_generation_pc['Year']>=1990]
elec_generation_pc.shape
# Out:
# (1360, 3)

# %%
elec_generation_pc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1360 entries, 28 to 6623
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Entity                        1360 non-null   object
#  1   Year                          1360 non-null   int64
#  2   Per capita electricity - kWh  1360 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 42.5+ KB

# %% [markdown]
# ## 5.Net electricity imports, 2023
#
# Net electricity imports are calculated as electricity imports minus exports. Countries with positive values are net importers of electricity;
# negative values are net exporters. Measured in terawatt-hours.
#
# https://ourworldindata.org/explorers/energy?region=Oceania&facet=none&Total+or+Breakdown=Total&Energy+or+Electricity=Electricity+only&Metric=Net+electricity+imports&country=USA~GBR~CHN~OWID_WRL~IND~BRA~ZAF

# %%
df5=pd.read_csv('/content/drive/MyDrive/Hamoye_capstone_project_data/net-electricity-imports.csv')
df5.head()
# Out:
#         Entity Code  Year  Net imports - TWh
# 0  Afghanistan  AFG  2000               0.09
# 1  Afghanistan  AFG  2001               0.09
# 2  Afghanistan  AFG  2002               0.10
# 3  Afghanistan  AFG  2003               0.10
# 4  Afghanistan  AFG  2004               0.10

# %%
df5.Entity.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Cyprus', 'Czechia',
#        'Democratic Republic of Congo', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'East Timor', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union (27)',
#        'Falkland Islands', 'Faroe Islands', 'Fiji', 'Finland', 'France',
#        'French Guiana', 'French Polynesia', 'Gabon', 'Gambia', 'Georgia',
#        'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guadeloupe', 'Guam', 'Guatemala', 'Guinea', 'Guinea-Bissau',
#        'Guyana', 'Haiti', 'High-income countries', 'Honduras',
#        'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran',
#        'Iraq', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan',
#        'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Lithuania', 'Low-income countries',
#        'Lower-middle-income countries', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Martinique', 'Mauritania', 'Mauritius', 'Mexico', 'Moldova',
#        'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique',
#        'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands',
#        'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria',
#        'Niue', 'North America', 'North Korea', 'North Macedonia',
#        'Norway', 'Oceania', 'Oman', 'Pakistan', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland',
#        'Portugal', 'Puerto Rico', 'Qatar', 'Reunion', 'Romania', 'Russia',
#        'Rwanda', 'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'Sao Tome and Principe', 'Saudi Arabia', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia',
#        'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa',
#        'South America', 'South Korea', 'South Sudan', 'Spain',
#        'Sri Lanka', 'Sudan', 'Suriname', 'Sweden', 'Switzerland', 'Syria',
#        'Taiwan', 'Tajikistan', 'Tanzania', 'Thailand', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'United States Virgin Islands', 'Upper-middle-income countries',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'Western Sahara', 'Yemen', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
#replace countries fron Entity with dict
df5.replace({"Entity": dict}, inplace=True)

# %%
#find countries which are now in countries_ssa
entity_ssa5=[]
for i in df5.Entity.unique():
  if i in countries_ssa:
    entity_ssa5.append(i)
len(entity_ssa5)
# Out:
# 49

# %%
#replace entities with dict_regions
df5.replace({"Entity": dict_regions}, inplace=True)

# %%
#find entities that are now in regions4 list
regions5=[]
for i in df5.Entity.unique():
  if i in regions4:
    regions5.append(i)

regions5
# Out:
# ['Africa ()',
#  'Asia ()',
#  'Europe ()',
#  'North America ()',
#  'Oceania ()',
#  'Latin America and Caribbean ()']

# %% [markdown]
# No World.

# %%
valid_entities = entity_ssa5 + regions5

# Select rows for valid entities
elec_imports = df5[df5['Entity'].isin(valid_entities)]

# Drop columns 'Code'
elec_imports = elec_imports.drop(['Code'], axis=1)
elec_imports.head()
# Out:
#        Entity  Year  Net imports - TWh
# 23  Africa ()  2000          13.070001
# 24  Africa ()  2001           3.150000
# 25  Africa ()  2002           1.640000
# 26  Africa ()  2003           1.340000
# 27  Africa ()  2004           1.360000

# %%
elec_imports.tail(20)
# Out:
#         Entity  Year  Net imports - TWh
# 5555  Zimbabwe  2003               3.18
# 5556  Zimbabwe  2004               2.04
# 5557  Zimbabwe  2005               2.98
# 5558  Zimbabwe  2006               3.90
# 5559  Zimbabwe  2007               2.93
# 5560  Zimbabwe  2008               1.12
# 5561  Zimbabwe  2009               1.28
# 5562  Zimbabwe  2010               0.73
# 5563  Zimbabwe  2011               0.60
# 5564  Zimbabwe  2012               0.55
# 5565  Zimbabwe  2013               0.53
# 5566  Zimbabwe  2014              -0.10
# 5567  Zimbabwe  2015              -0.10
# 5568  Zimbabwe  2016               1.85
# 5569  Zimbabwe  2017               2.22
# 5570  Zimbabwe  2018               1.02
# 5571  Zimbabwe  2019               1.11
# 5572  Zimbabwe  2020               1.98
# 5573  Zimbabwe  2021               1.74
# 5574  Zimbabwe  2022               1.76

# %%
elec_imports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1256 entries, 23 to 5574
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Entity             1256 non-null   object
#  1   Year               1256 non-null   int64
#  2   Net imports - TWh  1256 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 39.2+ KB

# %%
elec_imports.Year.unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022, 2023])

# %% [markdown]
# ## 6.Electricity demand, 2023
#
# Electricity demand is measured in terawatt-hours, as **total electricity generation, adjusted for electricity imports and exports**.
#
# Last updated
# May 8, 2024
#
# https://ourworldindata.org/grapher/electricity-demand

# %%
df6=pd.read_csv('/content/drive/MyDrive/Hamoye_capstone_project_data/electricity-demand.csv')
df6.head()
# Out:
#           Entity Code  Year  Electricity demand - TWh
# 0  ASEAN (Ember)  NaN  2000                    378.61
# 1  ASEAN (Ember)  NaN  2001                    404.85
# 2  ASEAN (Ember)  NaN  2002                    433.19
# 3  ASEAN (Ember)  NaN  2003                    458.24
# 4  ASEAN (Ember)  NaN  2004                    496.56

# %%
entity6=df6.Entity.unique()
entity6
# Out:
# array(['ASEAN (Ember)', 'Afghanistan', 'Africa', 'Africa (Ember)',
#        'Albania', 'Algeria', 'American Samoa', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Asia',
#        'Asia (Ember)', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas',
#        'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
#        'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Cyprus',
#        'Czechia', 'Democratic Republic of Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'East Timor', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'Europe (Ember)',
#        'European Union (27)', 'Falkland Islands', 'Faroe Islands', 'Fiji',
#        'Finland', 'France', 'French Guiana', 'French Polynesia',
#        'G20 (Ember)', 'G7 (Ember)', 'Gabon', 'Gambia', 'Georgia',
#        'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guadeloupe', 'Guam', 'Guatemala', 'Guinea', 'Guinea-Bissau',
#        'Guyana', 'Haiti', 'High-income countries', 'Honduras',
#        'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran',
#        'Iraq', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan',
#        'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latin America and Caribbean (Ember)',
#        'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Lithuania',
#        'Low-income countries', 'Lower-middle-income countries',
#        'Luxembourg', 'Macao', 'Madagascar', 'Malawi', 'Malaysia',
#        'Maldives', 'Mali', 'Malta', 'Martinique', 'Mauritania',
#        'Mauritius', 'Mexico', 'Middle East (Ember)', 'Moldova',
#        'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique',
#        'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands',
#        'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria',
#        'Niue', 'North America', 'North America (Ember)', 'North Korea',
#        'North Macedonia', 'Norway', 'OECD (Ember)', 'Oceania',
#        'Oceania (Ember)', 'Oman', 'Pakistan', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland',
#        'Portugal', 'Puerto Rico', 'Qatar', 'Reunion', 'Romania', 'Russia',
#        'Rwanda', 'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'Sao Tome and Principe', 'Saudi Arabia', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia',
#        'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa',
#        'South America', 'South Korea', 'South Sudan', 'Spain',
#        'Sri Lanka', 'Sudan', 'Suriname', 'Sweden', 'Switzerland', 'Syria',
#        'Taiwan', 'Tajikistan', 'Tanzania', 'Thailand', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'United States Virgin Islands', 'Upper-middle-income countries',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'Western Sahara', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
#replace countries fron Entity with dict
df6.replace({"Entity": dict}, inplace=True)

# %%
#find countries which are now in countries_ssa
entity_ssa6=[]
for i in df6.Entity.unique():
  if i in countries_ssa:
    entity_ssa6.append(i)
len(entity_ssa5)
# Out:
# 49

# %%
regions_ember
# Out:
# ['Africa (Ember)',
#  'Asia (Ember)',
#  'Europe (Ember)',
#  'Latin America and Caribbean (Ember)',
#  'Middle East (Ember)',
#  'North America (Ember)',
#  'Oceania (Ember)']

# %%
valid_entities = entity_ssa6 + regions_ember  + ['World']

# Select rows for valid entities
elec_generation_adj = df6[df6['Entity'].isin(valid_entities)]

# Drop columns 'Code'
elec_generation_adj = elec_generation_adj.drop(['Code'], axis=1)
elec_generation_adj.head()
# Out:
#             Entity  Year  Electricity demand - TWh
# 70  Africa (Ember)  2000                    441.08
# 71  Africa (Ember)  2001                    459.46
# 72  Africa (Ember)  2002                    487.69
# 73  Africa (Ember)  2003                    509.14
# 74  Africa (Ember)  2004                    540.14

# %%
elec_generation_adj['Entity'] = elec_generation_adj['Entity'].str.replace(' (Ember)', ' ()')
elec_generation_adj.head(2)
# Out:
#        Entity  Year  Electricity demand - TWh
# 70  Africa ()  2000                    441.08
# 71  Africa ()  2001                    459.46

# %%
elec_generation_adj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1310 entries, 70 to 5862
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Entity                    1310 non-null   object
#  1   Year                      1310 non-null   int64
#  2   Electricity demand - TWh  1310 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 40.9+ KB

# %% [markdown]
# ## 7.Number of people without access to electricity, 2019
# 1990-2019
#
# Having access to electricity is defined in international statistics as having an electricity source that can provide very basic
# lighting, and charge a phone or power a radio for 4 hours per day.
# https://ourworldindata.org/grapher/people-without-electricity-country

# %%
df7=pd.read_csv('/content/drive/MyDrive/Hamoye_capstone_project_data/people-without-electricity-country.csv')
df7.head()
# Out:
#         Entity Code  Year  Number of people without access to electricity
# 0  Afghanistan  AFG  2005                                     19934584.60
# 1  Afghanistan  AFG  2006                                     19005378.68
# 2  Afghanistan  AFG  2007                                     17913023.65
# 3  Afghanistan  AFG  2008                                     15968033.86
# 4  Afghanistan  AFG  2009                                     15469296.29

# %%
entity7=df7.Entity.unique()
entity7
# Out:
# array(['Afghanistan', 'Africa Eastern and Southern',
#        'Africa Western and Central', 'Albania', 'Algeria', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Arab World', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Caribbean Small States', 'Cayman Islands',
#        'Central African Republic', 'Central Europe and the Baltics',
#        'Chad', 'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba',
#        'Curacao', 'Cyprus', 'Czechia', 'Democratic Republic of Congo',
#        'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic',
#        'Early-demographic dividend', 'East Asia & Pacific',
#        'East Asia & Pacific (IDA & IBRD)',
#        'East Asia & Pacific (excluding high income)', 'East Timor',
#        'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Euro area',
#        'Europe & Central Asia', 'Europe & Central Asia (IDA & IBRD)',
#        'Europe & Central Asia (excluding high income)', 'European Union',
#        'Faroe Islands', 'Fiji', 'Finland',
#        'Fragile and conflict affected situations', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guam',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'Honduras', 'Hong Kong', 'Hungary', 'IBRD only',
#        'IDA & IBRD total', 'IDA blend', 'IDA only', 'IDA total',
#        'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan',
#        'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (IDA & IBRD)',
#        'Latin America & Caribbean (excluding high income)', 'Latvia',
#        'Least developed countries: UN classification', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
#        'Low & middle income', 'Low income', 'Lower middle income',
#        'Luxembourg', 'Macao', 'Madagascar', 'Malawi', 'Malaysia',
#        'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Mauritania',
#        'Mauritius', 'Mexico', 'Micronesia (country)',
#        'Middle East & North Africa',
#        'Middle East & North Africa (IDA & IBRD)',
#        'Middle East & North Africa (excluding high income)',
#        'Middle income', 'Moldova', 'Monaco', 'Mongolia', 'Montenegro',
#        'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
#        'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua',
#        'Niger', 'Nigeria', 'North America', 'North Korea',
#        'North Macedonia', 'Northern Mariana Islands', 'Norway',
#        'OECD members', 'Oman', 'Other small states',
#        'Pacific island small states', 'Pakistan', 'Palau', 'Palestine',
#        'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines',
#        'Poland', 'Portugal', 'Post-demographic dividend',
#        'Pre-demographic dividend', 'Puerto Rico', 'Qatar', 'Romania',
#        'Russia', 'Rwanda', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Martin (French part)', 'Saint Vincent and the Grenadines',
#        'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Small states', 'Solomon Islands', 'Somalia', 'South Africa',
#        'South Asia', 'South Asia (IDA & IBRD)', 'South Korea',
#        'South Sudan', 'Spain', 'Sri Lanka', 'Sub-Saharan Africa',
#        'Sub-Saharan Africa (IDA & IBRD)',
#        'Sub-Saharan Africa (excluding high income)', 'Sudan', 'Suriname',
#        'Sweden', 'Switzerland', 'Syria', 'Tajikistan', 'Tanzania',
#        'Thailand', 'Togo', 'Tonga', 'Trinidad and Tobago', 'Tunisia',
#        'Turkey', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu',
#        'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'United States Virgin Islands',
#        'Upper middle income', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela', 'Vietnam', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
#find countries which are now in countries_ssa
entity_ssa7=[]
for i in df7.Entity.unique():
  if i in countries_ssa:
    entity_ssa7.append(i)
len(entity_ssa7)
# Out:
# 45

# %%
set(countries_ssa)-set(entity_ssa7)
# Out:
# {'Cabo Verde', 'Congo, Dem. Rep.', 'Congo, Rep.', 'Gambia, The'}

# %%
#replace countries from Entity with dict
df7.replace({"Entity": dict}, inplace=True)

# %%
entity_ssa7=[]
for i in df7.Entity.unique():
  if i in countries_ssa:
    entity_ssa7.append(i)
len(entity_ssa7)
# Out:
# 49

# %%
regions_wb
# Out:
# ['East Asia and Pacific (WB)',
#  'Europe and Central Asia (WB)',
#  'Latin America and Caribbean (WB)',
#  'Middle East and North Africa (WB)',
#  'North America (WB)',
#  'South Asia (WB)',
#  'Sub-Saharan Africa (WB)']

# %%
dict_reg={'Latin America & Caribbean':'Latin America and Caribbean (WB)',
       'Europe & Central Asia':'Europe and Central Asia (WB)',
       'Middle East & North Africa':'Middle East and North Africa (WB)',
           'East Asia & Pacific':'East Asia and Pacific (WB)',
          'North America':'North America (WB)',
          'South Asia':'South Asia (WB)',
          'Sub-Saharan Africa':'Sub-Saharan Africa (WB)' }

# %%
#replace entities wit dict_reg
df7.replace({"Entity": dict_reg}, inplace=True)

# %%
#find entities in df7 which are in regions_wb
entity_region=[]
for i in df7.Entity.unique():
  if i in regions_wb:
    entity_region.append(i)
len(entity_region)
# Out:
# 7

# %%
valid_entities =regions_wb + countries_ssa + ['World']

# %%
# Select rows for valid entities
people_no_access = df7[df7['Entity'].isin(valid_entities)]

# Drop columns 'Code'
people_no_access = people_no_access.drop(['Code'], axis=1)
people_no_access.head()
# Out:
#      Entity  Year  Number of people without access to electricity
# 124  Angola  2001                                     13556602.40
# 125  Angola  2002                                     12897117.68
# 126  Angola  2003                                     13144298.22
# 127  Angola  2004                                     13405173.12
# 128  Angola  2005                                     13681991.06

# %% [markdown]
# # 8.Ember - Updated on 18 June 2024. Yearly electricity data
#
# https://ember-climate.org/data-catalogue/yearly-electricity-data/
# https://ember-climate.org/app/uploads/2022/07/yearly_full_release_long_format.csv

# %% [markdown]
# ## 8.1 Extract valid entities

# %%
path='/content/drive/MyDrive/Hamoye_capstone_project_data/yearly_full_release_long_format.csv'
df8=pd.read_csv(path)
df8.head()
# Out:
#           Area Country code  Year Area type Continent Ember region   EU  OECD  \
# 0  Afghanistan          AFG  2000   Country      Asia         Asia  0.0   0.0
# 1  Afghanistan          AFG  2000   Country      Asia         Asia  0.0   0.0
# 2  Afghanistan          AFG  2000   Country      Asia         Asia  0.0   0.0
# 3  Afghanistan          AFG  2000   Country      Asia         Asia  0.0   0.0
# 4  Afghanistan          AFG  2000   Country      Asia         Asia  0.0   0.0
#
#    G20   G7  ASEAN  Category     Subcategory  \
# 0  0.0  0.0    0.0  Capacity  Aggregate fuel
# 1  0.0  0.0    0.0  Capacity  Aggregate fuel
# 2  0.0  0.0    0.0  Capacity  Aggregate fuel
# 3  0.0  0.0    0.0  Capacity  Aggregate fuel
# 4  0.0  0.0    0.0  Capacity  Aggregate fuel
#
#                                 Variable Unit  Value  YoY absolute change  \
# 0                                  Clean   GW   0.19                  NaN
# 1                                 Fossil   GW   0.03                  NaN
# 2                   Gas and Other Fossil   GW   0.03                  NaN
# 3  Hydro, Bioenergy and Other Renewables   GW   0.19                  NaN
# 4                             Renewables   GW   0.19                  NaN
#
#    YoY % change
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
areas=df8.Area.unique()
areas
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'ASEAN', 'Asia', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas (the)', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bosnia Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia',
#        'Cameroon', 'Canada', 'Cayman Islands (the)',
#        'Central African Republic (the)', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros (the)',
#        'Congo (the Democratic Republic of the)', 'Congo (the)',
#        'Cook Islands (the)', 'Costa Rica', "Cote d'Ivoire", 'Croatia',
#        'Cuba', 'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic (the)', 'Ecuador', 'Egypt', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia',
#        'EU', 'Europe', 'Falkland Islands (the) [Malvinas]',
#        'Faroe Islands (the)', 'Fiji', 'Finland', 'France',
#        'French Guiana', 'French Polynesia', 'G20', 'G7', 'Gabon',
#        'Gambia (the)', 'Georgia', 'Germany', 'Ghana', 'Gibraltar',
#        'Greece', 'Greenland', 'Grenada', 'Guadeloupe', 'Guam',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran (Islamic Republic of)', 'Iraq', 'Ireland',
#        'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan',
#        'Kenya', 'Kiribati', "Korea (the Democratic People's Republic of)",
#        'Kosovo', 'Kuwait', 'Kyrgyzstan',
#        "Lao People's Democratic Republic (the)",
#        'Latin America and Caribbean', 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Lithuania', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Martinique', 'Mauritania', 'Mauritius', 'Mexico', 'Middle East',
#        'Moldova', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco',
#        'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
#        'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua',
#        'Niger (the)', 'Nigeria', 'Niue', 'North America',
#        'North Macedonia', 'Norway', 'Oceania', 'OECD', 'Oman', 'Pakistan',
#        'Palestine, State of', 'Panama', 'Papua New Guinea', 'Paraguay',
#        'Peru', 'Philippines (the)', 'Poland', 'Portugal', 'Puerto Rico',
#        'Qatar', 'Reunion', 'Romania', 'Russian Federation (the)',
#        'Rwanda', 'Saint Helena, Ascension and Tristan da Cunha',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'Sao Tome and Principe', 'Saudi Arabia', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia',
#        'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan (the)',
#        'Suriname', 'Sweden', 'Switzerland', 'Syrian Arab Republic (the)',
#        'Taiwan', 'Tajikistan', 'Tanzania, the United Republic of',
#        'Thailand', 'Timor-Leste', 'Togo', 'Tonga', 'Trinidad and Tobago',
#        'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands (the)', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom',
#        'United States of America', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela (Bolivarian Republic of)', 'Viet Nam',
#        'Virgin Islands (British)', 'Virgin Islands (U.S.)',
#        'Western Sahara', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
df8.Category.unique()
# Out:
# array(['Capacity', 'Electricity demand', 'Electricity generation',
#        'Electricity imports', 'Power sector emissions'], dtype=object)

# %%
countries_ssa
# Out:
# ['Angola',
#  'Burundi',
#  'Benin',
#  'Burkina Faso',
#  'Botswana',
#  'Central African Republic',
#  "Cote d'Ivoire",
#  'Cameroon',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Comoros',
#  'Cabo Verde',
#  'Djibouti',
#  'Eritrea',
#  'Ethiopia',
#  'Gabon',
#  'Ghana',
#  'Guinea',
#  'Gambia, The',
#  'Guinea-Bissau',
#  'Equatorial Guinea',
#  'Kenya',
#  'Liberia',
#  'Lesotho',
#  'Madagascar',
#  'Mali',
#  'Mozambique',
#  'Mauritania',
#  'Mauritius',
#  'Malawi',
#  'Namibia',
#  'Niger',
#  'Nigeria',
#  'Rwanda',
#  'Sudan',
#  'Senegal',
#  'Sierra Leone',
#  'Somalia',
#  'South Sudan',
#  'Sao Tome and Principe',
#  'Eswatini',
#  'Seychelles',
#  'Chad',
#  'Togo',
#  'Tanzania',
#  'Uganda',
#  'South Africa',
#  'Zambia',
#  'Zimbabwe']

# %%
#find areas which are i countries_ssa
areas_ssa=[]
for i in areas:
  if i in countries_ssa:
    areas_ssa.append(i)
len(areas_ssa)
# Out:
# 41

# %%
set(countries_ssa)-set(areas_ssa)
# Out:
# {'Central African Republic',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Gambia, The',
#  'Niger',
#  'Sudan',
#  'Tanzania'}

# %%
dict_area={'Central African Republic (the)':'Central African Republic',
 'Comoros (the)':'Comoros',
 'Congo (the Democratic Republic of the)':'Congo, Dem. Rep.',
        'Congo (the)':'Congo, Rep.',
        'Gambia (the)':'Gambia, The',
        'Niger (the)': 'Niger',
 'Sudan (the)':'Sudan',
 'Tanzania, the United Republic of':'Tanzania'}

# %%
#replace areas with dict_area
df8.replace({"Area": dict_area}, inplace=True)

# %%
#find areas which are i countries_ssa
areas_ssa=[]
for i in df8.Area.unique():
  if i in countries_ssa:
    areas_ssa.append(i)
len(areas_ssa)
# Out:
# 49

# %%
regions_un
# Out:
# ['Africa (UN)',
#  'Asia (UN)',
#  'Europe (UN)',
#  'Latin America and Caribbean (UN)',
#  'North America (UN)',
#  'Oceania (UN)']

# %%
regions_ember
# Out:
# ['Africa (Ember)',
#  'Asia (Ember)',
#  'Europe (Ember)',
#  'Latin America and Caribbean (Ember)',
#  'Middle East (Ember)',
#  'North America (Ember)',
#  'Oceania (Ember)']

# %%
regions_wb
# Out:
# ['East Asia and Pacific (WB)',
#  'Europe and Central Asia (WB)',
#  'Latin America and Caribbean (WB)',
#  'Middle East and North Africa (WB)',
#  'North America (WB)',
#  'South Asia (WB)',
#  'Sub-Saharan Africa (WB)']

# %%
dict_regions_ember= {'Africa':'Africa ()',
                     'Asia':'Asia ()',
                     'Europe':'Europe ()',
                     'Latin America and Caribbean':'Latin America and Caribbean ()',
                     'Middle East':'Middle East ()',
                     'North America':'North America ()',
                     'Oceania':'Oceania ()'}

# %%
#replace areas with dict_regions_ember
df8.replace({"Area": dict_regions_ember}, inplace=True)

# %%
#We replaces (Ember) with (), so now our regions_ember are:
regions_ember=['Africa ()', 'Asia ()', 'Europe ()', 'Latin America and Caribbean ()', 'Middle East ()', 'North America ()', 'Oceania ()']

# %%
area_regions=[]
for i in df8.Area.unique():
  if i in regions_ember:
    area_regions.append(i)
len(area_regions)
# Out:
# 7

# %%
valid_entities = countries_ssa + regions_ember  + ['World']

# Select rows for valid entities
df8_f = df8[df8['Area'].isin(valid_entities)]
df8_f.head(2)
# Out:
#            Area Country code  Year Area type Continent Ember region  EU  OECD  \
# 1518  Africa ()          NaN  2000    Region       NaN          NaN NaN   NaN
# 1519  Africa ()          NaN  2000    Region       NaN          NaN NaN   NaN
#
#       G20  G7  ASEAN  Category     Subcategory Variable Unit  Value  \
# 1518  NaN NaN    NaN  Capacity  Aggregate fuel    Clean   GW  23.81
# 1519  NaN NaN    NaN  Capacity  Aggregate fuel   Fossil   GW  70.39
#
#       YoY absolute change  YoY % change
# 1518                  NaN           NaN
# 1519                  NaN           NaN

# %%
df8_f.columns
# Out:
# Index(['Area', 'Country code', 'Year', 'Area type', 'Continent',
#        'Ember region', 'EU', 'OECD', 'G20', 'G7', 'ASEAN', 'Category',
#        'Subcategory', 'Variable', 'Unit', 'Value', 'YoY absolute change',
#        'YoY % change'],
#       dtype='object')

# %%
#drop columns 'Country code','Area type', 'Continent','Ember region', 'EU', 'OECD', 'G20', 'G7', 'ASEAN'
df8_f.drop(['Country code', 'Area type', 'Continent', 'Ember region', 'EU', 'OECD', 'G20', 'G7', 'ASEAN'], axis=1, inplace=True)
df8_f.head()
# Out:
# <ipython-input-128-e01e78cb1b86>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df8_f.drop(['Country code', 'Area type', 'Continent', 'Ember region', 'EU', 'OECD', 'G20', 'G7', 'ASEAN'], axis=1, inplace=True)
#            Area  Year  Category     Subcategory  \
# 1518  Africa ()  2000  Capacity  Aggregate fuel
# 1519  Africa ()  2000  Capacity  Aggregate fuel
# 1520  Africa ()  2000  Capacity  Aggregate fuel
# 1521  Africa ()  2000  Capacity  Aggregate fuel
# 1522  Africa ()  2000  Capacity  Aggregate fuel
#
#                                    Variable Unit  Value  YoY absolute change  \
# 1518                                  Clean   GW  23.81                  NaN
# 1519                                 Fossil   GW  70.39                  NaN
# 1520                   Gas and Other Fossil   GW  28.88                  NaN
# 1521  Hydro, Bioenergy and Other Renewables   GW  21.72                  NaN
# 1522                             Renewables   GW  21.87                  NaN
#
#       YoY % change
# 1518           NaN
# 1519           NaN
# 1520           NaN
# 1521           NaN
# 1522           NaN

# %%
#make columns lowercase,restart index
df8_f.reset_index(drop=True, inplace=True)
df8_f.columns=df8_f.columns.str.lower()
df8_f.head()
# Out:
#         area  year  category     subcategory  \
# 0  Africa ()  2000  Capacity  Aggregate fuel
# 1  Africa ()  2000  Capacity  Aggregate fuel
# 2  Africa ()  2000  Capacity  Aggregate fuel
# 3  Africa ()  2000  Capacity  Aggregate fuel
# 4  Africa ()  2000  Capacity  Aggregate fuel
#
#                                 variable unit  value  yoy absolute change  \
# 0                                  Clean   GW  23.81                  NaN
# 1                                 Fossil   GW  70.39                  NaN
# 2                   Gas and Other Fossil   GW  28.88                  NaN
# 3  Hydro, Bioenergy and Other Renewables   GW  21.72                  NaN
# 4                             Renewables   GW  21.87                  NaN
#
#    yoy % change
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %% [markdown]
# ## 8.2 Extract relevant indicators

# %%
df8_f.category.unique()
# Out:
# array(['Capacity', 'Electricity demand', 'Electricity generation',
#        'Electricity imports', 'Power sector emissions'], dtype=object)

# %%
df8_f.subcategory.unique()
# Out:
# array(['Aggregate fuel', 'Fuel', 'Demand', 'Demand per capita', 'Total',
#        'Electricity imports', 'CO2 intensity'], dtype=object)

# %%
#group by category, take unique subcategory for each category
df8_f.groupby(['category'])['subcategory'].unique()
# Out:
# category
# Capacity                                        [Aggregate fuel, Fuel]
# Electricity demand                         [Demand, Demand per capita]
# Electricity generation                   [Aggregate fuel, Fuel, Total]
# Electricity imports                              [Electricity imports]
# Power sector emissions    [Aggregate fuel, CO2 intensity, Fuel, Total]
# Name: subcategory, dtype: object

# %% [markdown]
# **Fuel Types** - Metodology https://ember-climate.org/data-catalogue/yearly-electricity-data/
#
# In our global dataset, fuel data is mapped into nine generation types: Bioenergy, Coal, Gas, Hydro, Nuclear, Other Fossil, Other Renewables, Solar, and Wind. In our European dataset, Coal is further split into Hard Coal and Lignite, and Wind into Onshore and Offshore wind.
# 1 Solar includes both solar thermal and solar photovoltaic generation, and where possible distributed solar generation is included.
# 2 Where possible, Hydro generation excludes any contribution from pumped hydro generation.
# 3 Bioenergy is classified as renewable, but caveats are attached. See below for details.
# 4 Other Renewables generation includes geothermal, tidal and wave generation.
# 5 Other Fossil generation includes generation from oil and petroleum products, as well as manufactured gases and waste.
# Bioenergy has typically been assumed (by the IPCC, the IEA, and many others) to be a renewable energy source, in that forest and energy crops can be regrown and replenished, unlike fossil fuels.
#
# **Electricity Generation and Net Imports Overview**
# Ember releases time series data of power generation, broken down by fuel type, and power imports. These figures are then combined to produce a total power demand time series for each country. “% share” values refer to the share of generation (this does not include net imports) and not the share of consumption unless otherwise specified. We provide data for 210 countries to 2022, and where possible have gathered 2023 data using national sources.
# Compiling a full dataset to 2023 requires using data at multiple timescales. Annual generation data is collected from both national and multi-country sources. For the most recent years, data is often not available. In these cases we use monthly data, which is reported on a shorter lag, to estimate the latest annual generation.
#
# Annual data
# Annual data is generally available until 2022. It is gathered from the Key Sources described below.
# Net imports are available until 2022 for all countries. In cases where generation data exists for 2022, but imports do not, imports are carried forward. Where net import data is not available for any years, values are assumed to be zero

# %% [markdown]
# ### 8.2.1 Electricity imports

# %%
#Take rows where subcategory is Electricity imports
elec_imports_new=df8_f[df8_f['subcategory']=='Electricity imports']
elec_imports_new
# Out:
#             area  year             category          subcategory     variable  \
# 48     Africa ()  2000  Electricity imports  Electricity imports  Net Imports
# 114    Africa ()  2001  Electricity imports  Electricity imports  Net Imports
# 180    Africa ()  2002  Electricity imports  Electricity imports  Net Imports
# 246    Africa ()  2003  Electricity imports  Electricity imports  Net Imports
# 312    Africa ()  2004  Electricity imports  Electricity imports  Net Imports
# ...          ...   ...                  ...                  ...          ...
# 86082   Zimbabwe  2018  Electricity imports  Electricity imports  Net Imports
# 86148   Zimbabwe  2019  Electricity imports  Electricity imports  Net Imports
# 86214   Zimbabwe  2020  Electricity imports  Electricity imports  Net Imports
# 86280   Zimbabwe  2021  Electricity imports  Electricity imports  Net Imports
# 86346   Zimbabwe  2022  Electricity imports  Electricity imports  Net Imports
#
#       unit  value  yoy absolute change  yoy % change
# 48     TWh    NaN                  NaN           NaN
# 114    TWh    NaN                  NaN           NaN
# 180    TWh    NaN                  NaN           NaN
# 246    TWh    NaN                  NaN           NaN
# 312    TWh    NaN                  NaN           NaN
# ...    ...    ...                  ...           ...
# 86082  TWh   1.02                -1.20        -54.05
# 86148  TWh   1.11                 0.09          8.82
# 86214  TWh   1.98                 0.87         78.38
# 86280  TWh   1.74                -0.24        -12.12
# 86346  TWh   1.76                 0.02          1.15
#
# [1310 rows x 9 columns]

# %%
# find data for 2023 in elec_imports_new
elec_imports_2023=elec_imports_new[elec_imports_new['year']==2023]
elec_imports_2023
# Out:
#                                  area  year             category  \
# 1566                        Africa ()  2023  Electricity imports
# 4668                          Asia ()  2023  Electricity imports
# 32058                       Europe ()  2023  Electricity imports
# 41232                           Kenya  2023  Electricity imports
# 42816  Latin America and Caribbean ()  2023  Electricity imports
# 55026                  Middle East ()  2023  Electricity imports
# 61164                         Nigeria  2023  Electricity imports
# 62748                North America ()  2023  Electricity imports
# 64332                      Oceania ()  2023  Electricity imports
# 74929                    South Africa  2023  Electricity imports
# 83310                           World  2023  Electricity imports
#
#                subcategory     variable unit  value  yoy absolute change  \
# 1566   Electricity imports  Net Imports  TWh    NaN                  NaN
# 4668   Electricity imports  Net Imports  TWh    NaN                  NaN
# 32058  Electricity imports  Net Imports  TWh    NaN                  NaN
# 41232  Electricity imports  Net Imports  TWh   0.79                 0.59
# 42816  Electricity imports  Net Imports  TWh    NaN                  NaN
# 55026  Electricity imports  Net Imports  TWh    NaN                  NaN
# 61164  Electricity imports  Net Imports  TWh   0.00                 0.00
# 62748  Electricity imports  Net Imports  TWh    NaN                  NaN
# 64332  Electricity imports  Net Imports  TWh    NaN                  NaN
# 74929  Electricity imports  Net Imports  TWh  -2.68                 0.96
# 83310  Electricity imports  Net Imports  TWh    NaN                  NaN
#
#        yoy % change
# 1566            NaN
# 4668            NaN
# 32058           NaN
# 41232         295.0
# 42816           NaN
# 55026           NaN
# 61164           NaN
# 62748           NaN
# 64332           NaN
# 74929           NaN
# 83310           NaN

# %% [markdown]
#  **So**, only 2 SSA countries have data for 2023. We already have data on imports for 2022, no sense to add this table.

# %% [markdown]
# ### 8.2.2 Demand, Demand per capita

# %%
#take rows for Demand subcategory
demand_new=df8_f[df8_f['subcategory']=='Demand']
demand_new
# Out:
#             area  year            category subcategory variable unit   value  \
# 15     Africa ()  2000  Electricity demand      Demand   Demand  TWh  441.08
# 81     Africa ()  2001  Electricity demand      Demand   Demand  TWh  459.46
# 147    Africa ()  2002  Electricity demand      Demand   Demand  TWh  487.69
# 213    Africa ()  2003  Electricity demand      Demand   Demand  TWh  509.14
# 279    Africa ()  2004  Electricity demand      Demand   Demand  TWh  540.14
# ...          ...   ...                 ...         ...      ...  ...     ...
# 86049   Zimbabwe  2018  Electricity demand      Demand   Demand  TWh   10.46
# 86115   Zimbabwe  2019  Electricity demand      Demand   Demand  TWh    9.60
# 86181   Zimbabwe  2020  Electricity demand      Demand   Demand  TWh    8.69
# 86247   Zimbabwe  2021  Electricity demand      Demand   Demand  TWh   10.20
# 86313   Zimbabwe  2022  Electricity demand      Demand   Demand  TWh   10.69
#
#        yoy absolute change  yoy % change
# 15                     NaN           NaN
# 81                   18.38          4.17
# 147                  28.23          6.14
# 213                  21.45          4.40
# 279                  31.00          6.09
# ...                    ...           ...
# 86049                 0.69          7.06
# 86115                -0.86         -8.22
# 86181                -0.91         -9.48
# 86247                 1.51         17.38
# 86313                 0.49          4.80
#
# [1310 rows x 9 columns]

# %% [markdown]
# It is the same indicator as elec_generation_adj we had earlier. Compare them.

# %%
elec_generation_adj
# Out:
#          Entity  Year  Electricity demand - TWh
# 70    Africa ()  2000                    441.08
# 71    Africa ()  2001                    459.46
# 72    Africa ()  2002                    487.69
# 73    Africa ()  2003                    509.14
# 74    Africa ()  2004                    540.14
# ...         ...   ...                       ...
# 5858   Zimbabwe  2018                     10.46
# 5859   Zimbabwe  2019                      9.60
# 5860   Zimbabwe  2020                      8.69
# 5861   Zimbabwe  2021                     10.20
# 5862   Zimbabwe  2022                     10.69
#
# [1310 rows x 3 columns]

# %% [markdown]
# So, the tables have the same data, no new info for 2023.

# %%
#take rows for Demand per capita
demand_pc_new=df8_f[df8_f['subcategory']=='Demand per capita']
demand_pc_new
# Out:
#             area  year            category        subcategory  \
# 16     Africa ()  2000  Electricity demand  Demand per capita
# 82     Africa ()  2001  Electricity demand  Demand per capita
# 148    Africa ()  2002  Electricity demand  Demand per capita
# 214    Africa ()  2003  Electricity demand  Demand per capita
# 280    Africa ()  2004  Electricity demand  Demand per capita
# ...          ...   ...                 ...                ...
# 86050   Zimbabwe  2018  Electricity demand  Demand per capita
# 86116   Zimbabwe  2019  Electricity demand  Demand per capita
# 86182   Zimbabwe  2020  Electricity demand  Demand per capita
# 86248   Zimbabwe  2021  Electricity demand  Demand per capita
# 86314   Zimbabwe  2022  Electricity demand  Demand per capita
#
#                 variable unit  value  yoy absolute change  yoy % change
# 16     Demand per capita  MWh   0.54                  NaN           NaN
# 82     Demand per capita  MWh   0.55                 0.01          1.85
# 148    Demand per capita  MWh   0.57                 0.02          3.64
# 214    Demand per capita  MWh   0.58                 0.01          1.75
# 280    Demand per capita  MWh   0.60                 0.02          3.45
# ...                  ...  ...    ...                  ...           ...
# 86050  Demand per capita  MWh   0.70                 0.04          6.06
# 86116  Demand per capita  MWh   0.63                -0.07        -10.00
# 86182  Demand per capita  MWh   0.56                -0.07        -11.11
# 86248  Demand per capita  MWh   0.64                 0.08         14.29
# 86314  Demand per capita  MWh   0.67                 0.03          4.69
#
# [1310 rows x 9 columns]

# %%
elec_generation_pc
# Out:
#          Entity  Year  Per capita electricity - kWh
# 28    Africa ()  1990                     499.52590
# 29    Africa ()  1991                     495.91983
# 30    Africa ()  1992                     487.95328
# 31    Africa ()  1993                     492.02423
# 32    Africa ()  1994                     497.29596
# ...         ...   ...                           ...
# 6619   Zimbabwe  2018                     627.15125
# 6620   Zimbabwe  2019                     552.92850
# 6621   Zimbabwe  2020                     428.21597
# 6622   Zimbabwe  2021                     528.96410
# 6623   Zimbabwe  2022                     547.16327
#
# [1360 rows x 3 columns]

# %% [markdown]
# The tables are different:
#
# elec_generation_pc is for
# Annual average electricity generation per person, measured in kilowatt-hours, while demand_pc_new is for adjusted electricity generation per person(plus imports).
# This indicator can be useful for our project. Let's add it.

# %%
#take columns area, year, value from demand_pc_new, rename columns as entity, elec_generation_adj_pc_mwh
demand_pc_new=demand_pc_new[['area','year','value']]
demand_pc_new.columns=['Entity','Year','el_demand_pc_mwh']
demand_pc_new
# Out:
#           Entity  Year  el_demand_pc_mwh
# 16     Africa ()  2000              0.54
# 82     Africa ()  2001              0.55
# 148    Africa ()  2002              0.57
# 214    Africa ()  2003              0.58
# 280    Africa ()  2004              0.60
# ...          ...   ...               ...
# 86050   Zimbabwe  2018              0.70
# 86116   Zimbabwe  2019              0.63
# 86182   Zimbabwe  2020              0.56
# 86248   Zimbabwe  2021              0.64
# 86314   Zimbabwe  2022              0.67
#
# [1310 rows x 3 columns]

# %%
#Rename  demand_pc_new df with elec_generation_adj_pc
elec_generation_adj_pc=demand_pc_new
elec_generation_adj_pc.head(2)
# Out:
#        Entity  Year  el_demand_pc_mwh
# 16  Africa ()  2000              0.54
# 82  Africa ()  2001              0.55

# %%
elec_generation_adj_pc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1310 entries, 16 to 86314
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Entity            1310 non-null   object
#  1   Year              1310 non-null   int64
#  2   el_demand_pc_mwh  1310 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 40.9+ KB

# %%
elec_generation_adj_pc.describe()
# Out:
#               Year  el_demand_pc_mwh
# count  1310.000000       1310.000000
# mean   2011.151145          1.183069
# std       6.698350          2.343755
# min    2000.000000          0.010000
# 25%    2005.000000          0.082500
# 50%    2011.000000          0.230000
# 75%    2017.000000          1.077500
# max    2023.000000         14.230000

# %% [markdown]
# ### 8.2.3 Electricity generation: Aggregate fuel, Fuel, Total

# %%
#take Electricity generation category Total subcategory from df8_f
elec_gen_total=df8_f[(df8_f['category']=='Electricity generation') & (df8_f['subcategory']=='Total')]
elec_gen_total
# Out:
#             area  year                category subcategory          variable  \
# 47     Africa ()  2000  Electricity generation       Total  Total Generation
# 113    Africa ()  2001  Electricity generation       Total  Total Generation
# 179    Africa ()  2002  Electricity generation       Total  Total Generation
# 245    Africa ()  2003  Electricity generation       Total  Total Generation
# 311    Africa ()  2004  Electricity generation       Total  Total Generation
# ...          ...   ...                     ...         ...               ...
# 86081   Zimbabwe  2018  Electricity generation       Total  Total Generation
# 86147   Zimbabwe  2019  Electricity generation       Total  Total Generation
# 86213   Zimbabwe  2020  Electricity generation       Total  Total Generation
# 86279   Zimbabwe  2021  Electricity generation       Total  Total Generation
# 86345   Zimbabwe  2022  Electricity generation       Total  Total Generation
#
#       unit   value  yoy absolute change  yoy % change
# 47     TWh  441.08                  NaN           NaN
# 113    TWh  459.46                18.38          4.17
# 179    TWh  487.69                28.23          6.14
# 245    TWh  509.14                21.45          4.40
# 311    TWh  540.14                31.00          6.09
# ...    ...     ...                  ...           ...
# 86081  TWh    9.44                 1.89         25.03
# 86147  TWh    8.49                -0.95        -10.06
# 86213  TWh    6.71                -1.78        -20.97
# 86279  TWh    8.46                 1.75         26.08
# 86345  TWh    8.93                 0.47          5.56
#
# [1310 rows x 9 columns]

# %% [markdown]
# Earlier we had elec_generation df, let's compare

# %%
elec_gen_total2023=elec_gen_total[elec_gen_total['year']==2023]
elec_gen_total2023
# Out:
#                                  area  year                category  \
# 1565                        Africa ()  2023  Electricity generation
# 4667                          Asia ()  2023  Electricity generation
# 32057                       Europe ()  2023  Electricity generation
# 41231                           Kenya  2023  Electricity generation
# 42815  Latin America and Caribbean ()  2023  Electricity generation
# 55025                  Middle East ()  2023  Electricity generation
# 61163                         Nigeria  2023  Electricity generation
# 62747                North America ()  2023  Electricity generation
# 64331                      Oceania ()  2023  Electricity generation
# 74928                    South Africa  2023  Electricity generation
# 83309                           World  2023  Electricity generation
#
#       subcategory          variable unit     value  yoy absolute change  \
# 1565        Total  Total Generation  TWh    878.76                -5.44
# 4667        Total  Total Generation  TWh  15249.14               718.68
# 32057       Total  Total Generation  TWh   4951.50               -99.80
# 41231       Total  Total Generation  TWh     12.22                -0.14
# 42815       Total  Total Generation  TWh   1791.51                57.26
# 55025       Total  Total Generation  TWh   1389.08                21.39
# 61163       Total  Total Generation  TWh     40.65                 3.67
# 62747       Total  Total Generation  TWh   4884.44               -62.68
# 64331       Total  Total Generation  TWh    331.09                 1.56
# 74928       Total  Total Generation  TWh    228.35               -10.36
# 83309       Total  Total Generation  TWh  29475.52               630.97
#
#        yoy % change
# 1565          -0.62
# 4667           4.95
# 32057         -1.98
# 41231         -1.13
# 42815          3.30
# 55025          1.56
# 61163          9.92
# 62747         -1.27
# 64331          0.47
# 74928         -4.34
# 83309          2.19

# %%
elec_generation
# Out:
#          Entity  Year  Electricity generation - TWh
# 123   Africa ()  2000                        441.08
# 124   Africa ()  2001                        459.46
# 125   Africa ()  2002                        487.69
# 126   Africa ()  2003                        509.14
# 127   Africa ()  2004                        540.14
# ...         ...   ...                           ...
# 7377   Zimbabwe  2018                          9.44
# 7378   Zimbabwe  2019                          8.49
# 7379   Zimbabwe  2020                          6.71
# 7380   Zimbabwe  2021                          8.46
# 7381   Zimbabwe  2022                          8.93
#
# [1340 rows x 3 columns]

# %%
#find rows for 2023 in elec_generation
elec_generation_2023=elec_generation[elec_generation['Year']==2023]
elec_generation_2023
# Out:
#                               Entity  Year  Electricity generation - TWh
# 146                        Africa ()  2023                        878.28
# 423                          Asia ()  2023                      15237.65
# 2238                       Europe ()  2023                       4951.58
# 3510                           Kenya  2023                         12.20
# 3666  Latin America and Caribbean ()  2023                       1806.93
# 4330                  Middle East ()  2023                       1389.08
# 4751                         Nigeria  2023                         40.65
# 4912                North America ()  2023                       4884.46
# 5132                      Oceania ()  2023                        331.07
# 6143                    South Africa  2023                        228.35
# 7312                           World  2023                      29479.05

# %%
elec_generation.Year.describe()
# Out:
# count    1340.000000
# mean     2010.722388
# std         7.232856
# min      1985.000000
# 25%      2005.000000
# 50%      2011.000000
# 75%      2017.000000
# max      2023.000000
# Name: Year, dtype: float64

# %% [markdown]
# So, the new Ember table doesn't give us new info for 2023, only yoy absolute change and yoy % change. No need to add the table.

# %%
elec_generation.columns
# Out:
# Index(['Entity', 'Year', 'Electricity generation - TWh'], dtype='object')

# %% [markdown]
# # 9.Merge tables

# %%
access_consum.shape
# Out:
# (1987, 5)

# %%
# merge tables access_consum and elec_generation  on common year, entity
merged1=pd.merge(access_consum,elec_generation, on=['Entity','Year'], how='outer')
merged1.head()
# Out:
#       Entity  Year  Access to electricity (% of population)  \
# 0  Africa ()  1990                                      NaN
# 1  Africa ()  1991                                      NaN
# 2  Africa ()  1992                                      NaN
# 3  Africa ()  1993                                      NaN
# 4  Africa ()  1994                                      NaN
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Population (historical estimates)  Electricity generation - TWh
# 0                        638157248.0                           NaN
# 1                        655040512.0                           NaN
# 2                        671931520.0                           NaN
# 3                        689139968.0                           NaN
# 4                        706488256.0                           NaN

# %%
merged1.shape
# Out:
# (2085, 6)

# %%
#add elec_generation_pc to merged1
merged2=pd.merge(merged1,elec_generation_pc, on=['Entity','Year'], how='outer')
merged2.head()
# Out:
#       Entity  Year  Access to electricity (% of population)  \
# 0  Africa ()  1990                                      NaN
# 1  Africa ()  1991                                      NaN
# 2  Africa ()  1992                                      NaN
# 3  Africa ()  1993                                      NaN
# 4  Africa ()  1994                                      NaN
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Population (historical estimates)  Electricity generation - TWh  \
# 0                        638157248.0                           NaN
# 1                        655040512.0                           NaN
# 2                        671931520.0                           NaN
# 3                        689139968.0                           NaN
# 4                        706488256.0                           NaN
#
#    Per capita electricity - kWh
# 0                     499.52590
# 1                     495.91983
# 2                     487.95328
# 3                     492.02423
# 4                     497.29596

# %%
merged2.shape
# Out:
# (2085, 7)

# %%
#add elec_production to merged2
merged3=pd.merge(merged2,elec_production, on=['Entity','Year'], how='outer')
merged3.head()
# Out:
#       Entity  Year  Access to electricity (% of population)  \
# 0  Africa ()  1990                                      NaN
# 1  Africa ()  1991                                      NaN
# 2  Africa ()  1992                                      NaN
# 3  Africa ()  1993                                      NaN
# 4  Africa ()  1994                                      NaN
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Population (historical estimates)  Electricity generation - TWh  \
# 0                        638157248.0                           NaN
# 1                        655040512.0                           NaN
# 2                        671931520.0                           NaN
# 3                        689139968.0                           NaN
# 4                        706488256.0                           NaN
#
#    Per capita electricity - kWh  Electricity from coal - TWh  \
# 0                     499.52590                          NaN
# 1                     495.91983                          NaN
# 2                     487.95328                          NaN
# 3                     492.02423                          NaN
# 4                     497.29596                          NaN
#
#    Electricity from gas - TWh  Electricity from nuclear - TWh  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4                         NaN                             NaN
#
#    Electricity from hydro - TWh  Electricity from solar - TWh  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    Electricity from oil - TWh  Electricity from wind - TWh  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    Electricity from bioenergy - TWh  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    Other renewables excluding bioenergy - TWh
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN

# %%
merged3.shape
# Out:
# (2085, 16)

# %%
#add elec_imports to merged3
merged4=pd.merge(merged3,elec_imports, on=['Entity','Year'], how='outer')
merged4.head()
# Out:
#       Entity  Year  Access to electricity (% of population)  \
# 0  Africa ()  1990                                      NaN
# 1  Africa ()  1991                                      NaN
# 2  Africa ()  1992                                      NaN
# 3  Africa ()  1993                                      NaN
# 4  Africa ()  1994                                      NaN
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Population (historical estimates)  Electricity generation - TWh  \
# 0                        638157248.0                           NaN
# 1                        655040512.0                           NaN
# 2                        671931520.0                           NaN
# 3                        689139968.0                           NaN
# 4                        706488256.0                           NaN
#
#    Per capita electricity - kWh  Electricity from coal - TWh  \
# 0                     499.52590                          NaN
# 1                     495.91983                          NaN
# 2                     487.95328                          NaN
# 3                     492.02423                          NaN
# 4                     497.29596                          NaN
#
#    Electricity from gas - TWh  Electricity from nuclear - TWh  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4                         NaN                             NaN
#
#    Electricity from hydro - TWh  Electricity from solar - TWh  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    Electricity from oil - TWh  Electricity from wind - TWh  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    Electricity from bioenergy - TWh  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    Other renewables excluding bioenergy - TWh  Net imports - TWh
# 0                                         NaN                NaN
# 1                                         NaN                NaN
# 2                                         NaN                NaN
# 3                                         NaN                NaN
# 4                                         NaN                NaN

# %%
merged4.shape
# Out:
# (2085, 17)

# %%
#add elec_generation_adj to merged4
merged5=pd.merge(merged4,elec_generation_adj, on=['Entity','Year'], how='outer')
merged5.head()
# Out:
#       Entity  Year  Access to electricity (% of population)  \
# 0  Africa ()  1990                                      NaN
# 1  Africa ()  1991                                      NaN
# 2  Africa ()  1992                                      NaN
# 3  Africa ()  1993                                      NaN
# 4  Africa ()  1994                                      NaN
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Population (historical estimates)  Electricity generation - TWh  \
# 0                        638157248.0                           NaN
# 1                        655040512.0                           NaN
# 2                        671931520.0                           NaN
# 3                        689139968.0                           NaN
# 4                        706488256.0                           NaN
#
#    Per capita electricity - kWh  Electricity from coal - TWh  \
# 0                     499.52590                          NaN
# 1                     495.91983                          NaN
# 2                     487.95328                          NaN
# 3                     492.02423                          NaN
# 4                     497.29596                          NaN
#
#    Electricity from gas - TWh  Electricity from nuclear - TWh  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4                         NaN                             NaN
#
#    Electricity from hydro - TWh  Electricity from solar - TWh  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    Electricity from oil - TWh  Electricity from wind - TWh  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    Electricity from bioenergy - TWh  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    Other renewables excluding bioenergy - TWh  Net imports - TWh  \
# 0                                         NaN                NaN
# 1                                         NaN                NaN
# 2                                         NaN                NaN
# 3                                         NaN                NaN
# 4                                         NaN                NaN
#
#    Electricity demand - TWh
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
#add people_no_access to merged5 for adjusted(import/export) electricity generation per person
merged6=pd.merge(merged5,people_no_access, on=['Entity','Year'], how='outer')
merged6.head()
# Out:
#       Entity  Year  Access to electricity (% of population)  \
# 0  Africa ()  1990                                      NaN
# 1  Africa ()  1991                                      NaN
# 2  Africa ()  1992                                      NaN
# 3  Africa ()  1993                                      NaN
# 4  Africa ()  1994                                      NaN
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Population (historical estimates)  Electricity generation - TWh  \
# 0                        638157248.0                           NaN
# 1                        655040512.0                           NaN
# 2                        671931520.0                           NaN
# 3                        689139968.0                           NaN
# 4                        706488256.0                           NaN
#
#    Per capita electricity - kWh  Electricity from coal - TWh  \
# 0                     499.52590                          NaN
# 1                     495.91983                          NaN
# 2                     487.95328                          NaN
# 3                     492.02423                          NaN
# 4                     497.29596                          NaN
#
#    Electricity from gas - TWh  Electricity from nuclear - TWh  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4                         NaN                             NaN
#
#    Electricity from hydro - TWh  Electricity from solar - TWh  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    Electricity from oil - TWh  Electricity from wind - TWh  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    Electricity from bioenergy - TWh  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    Other renewables excluding bioenergy - TWh  Net imports - TWh  \
# 0                                         NaN                NaN
# 1                                         NaN                NaN
# 2                                         NaN                NaN
# 3                                         NaN                NaN
# 4                                         NaN                NaN
#
#    Electricity demand - TWh  Number of people without access to electricity
# 0                       NaN                                             NaN
# 1                       NaN                                             NaN
# 2                       NaN                                             NaN
# 3                       NaN                                             NaN
# 4                       NaN                                             NaN

# %%
# add elec_generation_adj_pc to merged6_1990 on common year, entity
merged7=pd.merge(merged6,elec_generation_adj_pc, on=['Entity','Year'], how='outer')
merged7.head()
# Out:
#       Entity  Year  Access to electricity (% of population)  \
# 0  Africa ()  1990                                      NaN
# 1  Africa ()  1991                                      NaN
# 2  Africa ()  1992                                      NaN
# 3  Africa ()  1993                                      NaN
# 4  Africa ()  1994                                      NaN
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Population (historical estimates)  Electricity generation - TWh  \
# 0                        638157248.0                           NaN
# 1                        655040512.0                           NaN
# 2                        671931520.0                           NaN
# 3                        689139968.0                           NaN
# 4                        706488256.0                           NaN
#
#    Per capita electricity - kWh  Electricity from coal - TWh  \
# 0                     499.52590                          NaN
# 1                     495.91983                          NaN
# 2                     487.95328                          NaN
# 3                     492.02423                          NaN
# 4                     497.29596                          NaN
#
#    Electricity from gas - TWh  Electricity from nuclear - TWh  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4                         NaN                             NaN
#
#    Electricity from hydro - TWh  Electricity from solar - TWh  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    Electricity from oil - TWh  Electricity from wind - TWh  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    Electricity from bioenergy - TWh  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    Other renewables excluding bioenergy - TWh  Net imports - TWh  \
# 0                                         NaN                NaN
# 1                                         NaN                NaN
# 2                                         NaN                NaN
# 3                                         NaN                NaN
# 4                                         NaN                NaN
#
#    Electricity demand - TWh  Number of people without access to electricity  \
# 0                       NaN                                             NaN
# 1                       NaN                                             NaN
# 2                       NaN                                             NaN
# 3                       NaN                                             NaN
# 4                       NaN                                             NaN
#
#    el_demand_pc_mwh
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
merged7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2085 entries, 0 to 2084
# Data columns (total 20 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Entity                                              2085 non-null   object
#  1   Year                                                2085 non-null   int64
#  2   Access to electricity (% of population)             1484 non-null   float64
#  3   Primary energy consumption per capita (kWh/person)  1576 non-null   float64
#  4   Population (historical estimates)                   1792 non-null   float64
#  5   Electricity generation - TWh                        1340 non-null   float64
#  6   Per capita electricity - kWh                        1360 non-null   float64
#  7   Electricity from coal - TWh                         1330 non-null   float64
#  8   Electricity from gas - TWh                          1330 non-null   float64
#  9   Electricity from nuclear - TWh                      1452 non-null   float64
#  10  Electricity from hydro - TWh                        1330 non-null   float64
#  11  Electricity from solar - TWh                        1330 non-null   float64
#  12  Electricity from oil - TWh                          1330 non-null   float64
#  13  Electricity from wind - TWh                         1330 non-null   float64
#  14  Electricity from bioenergy - TWh                    1310 non-null   float64
#  15  Other renewables excluding bioenergy - TWh          1286 non-null   float64
#  16  Net imports - TWh                                   1256 non-null   float64
#  17  Electricity demand - TWh                            1310 non-null   float64
#  18  Number of people without access to electricity      1333 non-null   float64
#  19  el_demand_pc_mwh                                    1310 non-null   float64
# dtypes: float64(18), int64(1), object(1)
# memory usage: 325.9+ KB

# %%
merged7.describe()
# Out:
#               Year  Access to electricity (% of population)  \
# count  2085.000000                              1484.000000
# mean   2006.185612                                44.090754
# std       9.547064                                30.579460
# min    1985.000000                                 0.533899
# 25%    1998.000000                                17.096379
# 50%    2006.000000                                38.018265
# 75%    2014.000000                                65.014345
# max    2023.000000                               100.000000
#
#        Primary energy consumption per capita (kWh/person)  \
# count                                        1576.000000
# mean                                         4281.153401
# std                                          7857.723361
# min                                            99.053375
# 25%                                           574.033783
# 50%                                          1455.430000
# 75%                                          3369.350825
# max                                         57886.984000
#
#        Population (historical estimates)  Electricity generation - TWh  \
# count                       1.792000e+03                   1340.000000
# mean                        2.506803e+08                    940.274840
# std                         1.026765e+09                   3542.169122
# min                         7.107300e+04                      0.020000
# 25%                         2.312693e+06                      0.340000
# 50%                         1.081645e+07                      1.805000
# 75%                         2.887949e+07                     11.670000
# max                         7.909295e+09                  29479.050000
#
#        Per capita electricity - kWh  Electricity from coal - TWh  \
# count                   1360.000000                  1330.000000
# mean                    1165.801660                   349.630826
# std                     2156.868093                  1432.876301
# min                        4.992966                     0.000000
# 25%                       78.140165                     0.000000
# 50%                      242.129830                     0.000000
# 75%                      779.742910                     0.185000
# max                     9946.666000                 10467.930000
#
#        Electricity from gas - TWh  Electricity from nuclear - TWh  \
# count                 1330.000000                     1452.000000
# mean                   192.391906                      103.006030
# std                    741.751618                      424.869579
# min                      0.000000                        0.000000
# 25%                      0.000000                        0.000000
# 50%                      0.000000                        0.000000
# 75%                      0.890000                        0.000000
# max                   6622.930000                     2762.240000
#
#        Electricity from hydro - TWh  Electricity from solar - TWh  \
# count                   1330.000000                   1330.000000
# mean                     146.686472                     11.718826
# std                      558.165267                     86.742597
# min                        0.000000                      0.000000
# 25%                        0.010000                      0.000000
# 50%                        0.751000                      0.000000
# 75%                        5.925000                      0.020000
# max                     4344.050000                   1629.900000
#
#        Electricity from oil - TWh  Electricity from wind - TWh  \
# count                 1330.000000                  1330.000000
# mean                    49.579214                    26.133278
# std                    192.165760                   150.422714
# min                      0.000000                     0.000000
# 25%                      0.030000                     0.000000
# 50%                      0.250000                     0.000000
# 75%                      1.137500                     0.000000
# max                   1364.684400                  2304.440000
#
#        Electricity from bioenergy - TWh  \
# count                       1310.000000
# mean                          14.018229
# std                           63.392902
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            0.110000
# max                          678.740000
#
#        Other renewables excluding bioenergy - TWh  Net imports - TWh  \
# count                                 1286.000000        1256.000000
# mean                                     2.475062           0.138328
# std                                      9.867454           2.173467
# min                                      0.000000         -15.659997
# 25%                                      0.000000           0.000000
# 50%                                      0.000000           0.000000
# 75%                                      0.000000           0.252500
# max                                     89.810000          19.570000
#
#        Electricity demand - TWh  \
# count               1310.000000
# mean                 817.615786
# std                 3358.035565
# min                    0.020000
# 25%                    0.440000
# 50%                    2.085000
# 75%                   10.527500
# max                29479.050000
#
#        Number of people without access to electricity  el_demand_pc_mwh
# count                                    1.333000e+03       1310.000000
# mean                                     5.106714e+07          1.183069
# std                                      1.778462e+08          2.343755
# min                                      0.000000e+00          0.010000
# 25%                                      1.339849e+06          0.082500
# 50%                                      8.501947e+06          0.230000
# 75%                                      1.733485e+07          1.077500
# max                                      1.627944e+09         14.230000

# %%
#drop years below 1990
merged7_1990=merged7[merged7['Year']>=1990]
merged7_1990.shape
# Out:
# (2075, 20)

# %%
merged7_1990.columns
# Out:
# Index(['Entity', 'Year', 'Access to electricity (% of population)',
#        'Primary energy consumption per capita (kWh/person)',
#        'Population (historical estimates)', 'Electricity generation - TWh',
#        'Per capita electricity - kWh', 'Electricity from coal - TWh',
#        'Electricity from gas - TWh', 'Electricity from nuclear - TWh',
#        'Electricity from hydro - TWh', 'Electricity from solar - TWh',
#        'Electricity from oil - TWh', 'Electricity from wind - TWh',
#        'Electricity from bioenergy - TWh',
#        'Other renewables excluding bioenergy - TWh', 'Net imports - TWh',
#        'Electricity demand - TWh',
#        'Number of people without access to electricity', 'el_demand_pc_mwh'],
#       dtype='object')

# %%
#make columns lowercase
merged7_1990.columns=merged7_1990.columns.str.lower()
merged7_1990.head()
# Out:
#       entity  year  access to electricity (% of population)  \
# 0  Africa ()  1990                                      NaN
# 1  Africa ()  1991                                      NaN
# 2  Africa ()  1992                                      NaN
# 3  Africa ()  1993                                      NaN
# 4  Africa ()  1994                                      NaN
#
#    primary energy consumption per capita (kwh/person)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    population (historical estimates)  electricity generation - twh  \
# 0                        638157248.0                           NaN
# 1                        655040512.0                           NaN
# 2                        671931520.0                           NaN
# 3                        689139968.0                           NaN
# 4                        706488256.0                           NaN
#
#    per capita electricity - kwh  electricity from coal - twh  \
# 0                     499.52590                          NaN
# 1                     495.91983                          NaN
# 2                     487.95328                          NaN
# 3                     492.02423                          NaN
# 4                     497.29596                          NaN
#
#    electricity from gas - twh  electricity from nuclear - twh  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4                         NaN                             NaN
#
#    electricity from hydro - twh  electricity from solar - twh  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    electricity from oil - twh  electricity from wind - twh  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    electricity from bioenergy - twh  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    other renewables excluding bioenergy - twh  net imports - twh  \
# 0                                         NaN                NaN
# 1                                         NaN                NaN
# 2                                         NaN                NaN
# 3                                         NaN                NaN
# 4                                         NaN                NaN
#
#    electricity demand - twh  number of people without access to electricity  \
# 0                       NaN                                             NaN
# 1                       NaN                                             NaN
# 2                       NaN                                             NaN
# 3                       NaN                                             NaN
# 4                       NaN                                             NaN
#
#    el_demand_pc_mwh
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
merged7_1990.columns
# Out:
# Index(['entity', 'year', 'access to electricity (% of population)',
#        'primary energy consumption per capita (kwh/person)',
#        'population (historical estimates)', 'electricity generation - twh',
#        'per capita electricity - kwh', 'electricity from coal - twh',
#        'electricity from gas - twh', 'electricity from nuclear - twh',
#        'electricity from hydro - twh', 'electricity from solar - twh',
#        'electricity from oil - twh', 'electricity from wind - twh',
#        'electricity from bioenergy - twh',
#        'other renewables excluding bioenergy - twh', 'net imports - twh',
#        'electricity demand - twh',
#        'number of people without access to electricity', 'el_demand_pc_mwh'],
#       dtype='object')

# %%
dict_columns= {'access to electricity (% of population)' :'access_to_electricity',
       'primary energy consumption per capita (kwh/person)':'primary_energy_consumption_pc',
       'population (historical estimates)':'population', 'electricity generation - twh':'electricity_generation',
       'per capita electricity - kwh':'electricity_pc', 'electricity from coal - twh':'electricity_from_coal',
       'electricity from gas - twh':'electricity_from_gas', 'electricity from nuclear - twh':'electricity_from_nuclear',
       'electricity from hydro - twh':'electricity_from_hydro', 'electricity from solar - twh':'electricity_from_solar',
       'electricity from oil - twh':'electricity_from_oil', 'electricity from wind - twh':'electricity_from_wind',
       'electricity from bioenergy - twh':'electricity_from_bioenergy', 'electricity demand - twh':'el_demand'}

# %%
#rename columns with dict_columns
merged7_1990.rename(columns=dict_columns, inplace=True)
merged7_1990.head()
# Out:
# <ipython-input-171-26d8b78a0862>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged7_1990.rename(columns=dict_columns, inplace=True)
#       entity  year  access_to_electricity  primary_energy_consumption_pc  \
# 0  Africa ()  1990                    NaN                            NaN
# 1  Africa ()  1991                    NaN                            NaN
# 2  Africa ()  1992                    NaN                            NaN
# 3  Africa ()  1993                    NaN                            NaN
# 4  Africa ()  1994                    NaN                            NaN
#
#     population  electricity_generation  electricity_pc  electricity_from_coal  \
# 0  638157248.0                     NaN       499.52590                    NaN
# 1  655040512.0                     NaN       495.91983                    NaN
# 2  671931520.0                     NaN       487.95328                    NaN
# 3  689139968.0                     NaN       492.02423                    NaN
# 4  706488256.0                     NaN       497.29596                    NaN
#
#    electricity_from_gas  electricity_from_nuclear  electricity_from_hydro  \
# 0                   NaN                       NaN                     NaN
# 1                   NaN                       NaN                     NaN
# 2                   NaN                       NaN                     NaN
# 3                   NaN                       NaN                     NaN
# 4                   NaN                       NaN                     NaN
#
#    electricity_from_solar  electricity_from_oil  electricity_from_wind  \
# 0                     NaN                   NaN                    NaN
# 1                     NaN                   NaN                    NaN
# 2                     NaN                   NaN                    NaN
# 3                     NaN                   NaN                    NaN
# 4                     NaN                   NaN                    NaN
#
#    electricity_from_bioenergy  other renewables excluding bioenergy - twh  \
# 0                         NaN                                         NaN
# 1                         NaN                                         NaN
# 2                         NaN                                         NaN
# 3                         NaN                                         NaN
# 4                         NaN                                         NaN
#
#    net imports - twh  el_demand  \
# 0                NaN        NaN
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN
#
#    number of people without access to electricity  el_demand_pc_mwh
# 0                                             NaN               NaN
# 1                                             NaN               NaN
# 2                                             NaN               NaN
# 3                                             NaN               NaN
# 4                                             NaN               NaN

# %%
# %pip install sidetable
# Out:
# Requirement already satisfied: sidetable in /usr/local/lib/python3.10/dist-packages (0.9.1)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from sidetable) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->sidetable) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->sidetable) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->sidetable) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->sidetable) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0->sidetable) (1.16.0)

# %%
import sidetable as stb

# %%
world_data=merged7_1990.copy()
world_data
# Out:
#          entity  year  access_to_electricity  primary_energy_consumption_pc  \
# 0     Africa ()  1990                    NaN                            NaN
# 1     Africa ()  1991                    NaN                            NaN
# 2     Africa ()  1992                    NaN                            NaN
# 3     Africa ()  1993                    NaN                            NaN
# 4     Africa ()  1994                    NaN                            NaN
# ...         ...   ...                    ...                            ...
# 2075       Togo  2022                    NaN                            NaN
# 2076     Uganda  2022                    NaN                            NaN
# 2082      World  2023                    NaN                            NaN
# 2083     Zambia  2022                    NaN                            NaN
# 2084   Zimbabwe  2022                    NaN                            NaN
#
#        population  electricity_generation  electricity_pc  \
# 0     638157248.0                     NaN       499.52590
# 1     655040512.0                     NaN       495.91983
# 2     671931520.0                     NaN       487.95328
# 3     689139968.0                     NaN       492.02423
# 4     706488256.0                     NaN       497.29596
# ...           ...                     ...             ...
# 2075          NaN                    0.88        99.44964
# 2076          NaN                    5.39       114.07506
# 2082          NaN                29479.05      3664.12800
# 2083          NaN                   19.47       972.64070
# 2084          NaN                    8.93       547.16327
#
#       electricity_from_coal  electricity_from_gas  electricity_from_nuclear  \
# 0                       NaN                   NaN                       NaN
# 1                       NaN                   NaN                       NaN
# 2                       NaN                   NaN                       NaN
# 3                       NaN                   NaN                       NaN
# 4                       NaN                   NaN                       NaN
# ...                     ...                   ...                       ...
# 2075                   0.00                  0.59                      0.00
# 2076                   0.00                  0.00                      0.00
# 2082               10467.93               6622.93                   2685.74
# 2083                   2.16                  0.00                      0.00
# 2084                   2.92                  0.00                      0.00
#
#       electricity_from_hydro  electricity_from_solar  electricity_from_oil  \
# 0                        NaN                     NaN                   NaN
# 1                        NaN                     NaN                   NaN
# 2                        NaN                     NaN                   NaN
# 3                        NaN                     NaN                   NaN
# 4                        NaN                     NaN                   NaN
# ...                      ...                     ...                   ...
# 2075                    0.16                    0.06                  0.07
# 2076                    4.81                    0.13                  0.06
# 2082                 4211.01                 1629.90                788.55
# 2083                   17.09                    0.14                  0.00
# 2084                    5.88                    0.03                  0.00
#
#       electricity_from_wind  electricity_from_bioenergy  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# ...                     ...                         ...
# 2075                   0.00                        0.00
# 2076                   0.00                        0.39
# 2082                2304.44                      678.74
# 2083                   0.00                        0.08
# 2084                   0.00                        0.10
#
#       other renewables excluding bioenergy - twh  net imports - twh  \
# 0                                            NaN                NaN
# 1                                            NaN                NaN
# 2                                            NaN                NaN
# 3                                            NaN                NaN
# 4                                            NaN                NaN
# ...                                          ...                ...
# 2075                                        0.00               0.80
# 2076                                        0.00              -0.31
# 2082                                       89.81                NaN
# 2083                                        0.00              -2.12
# 2084                                        0.00               1.76
#
#       el_demand  number of people without access to electricity  \
# 0           NaN                                             NaN
# 1           NaN                                             NaN
# 2           NaN                                             NaN
# 3           NaN                                             NaN
# 4           NaN                                             NaN
# ...         ...                                             ...
# 2075       1.68                                             NaN
# 2076       5.08                                             NaN
# 2082   29479.05                                             NaN
# 2083      17.35                                             NaN
# 2084      10.69                                             NaN
#
#       el_demand_pc_mwh
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 2075              0.19
# 2076              0.11
# 2082              3.73
# 2083              0.89
# 2084              0.67
#
# [2075 rows x 20 columns]

# %%
#turn merged_ssa to csv file
world_data.to_csv('world_data.csv',index=False)

# %%
from google.colab import files
files.download('world_data.csv')
